# %% [markdown]
# # Aprendizaje por refuerzo
#
# ## Resolución de CartPole mediante Q-Learning
#
# En este *notebook* se resolverá el entorno CartPole utilizando el algoritmo Q-Learning.
#
# ### Discretización
#
# Una característica importante de CartPole es que sus estados son continuos, lo que, en principio, impide poder acceder y modificar la tabla Q (discreta) según estos valores.
#
# La solución en este caso es cuantizar o discretizar los valores continuos. Para esto podemos dividir los posibles valores continuos en *rangos* (llamados *bins*).
#
# Por ejemplo, si tenemos un estado continuo en el rango [0,1] y queremos discretizarlo en 10 posibles *bins*, estos quedarían como:
#
# * Valores en [0, 0.1) = Bin 0
# * Valores en [0.1, 0.2) = Bin 1
# ...
# * Valores en [0.9,1] = Bin 9
#
# De este modo, si el estado observado fuese **0.15** indexaríamos la tabla Q como si fuese **1**.
#
# Para CartPole solo es necesario discretizar los estados pero esta misma técnica podría utilizarse también en el caso de que fuese necesario discretizar las acciones.
#
#
#
# ---

# %% [markdown]
# Como en el ejercicio anterior, hacemos uso de una serie de librerías para poder mostrar los resultados como vídeos:

# %%
# !pip install gym pyvirtualdisplay > /dev/null 2>&1

# !apt-get install -y xvfb python-opengl ffmpeg > /dev/null 2>&1

import gym
from gym import logger as gymlogger
from gym.wrappers.record_video import RecordVideo
gymlogger.set_level(40) #error only

import math
import glob
import io
import base64
from IPython.display import HTML
from IPython import display as ipythondisplay
from pyvirtualdisplay import Display
display = Display(visible=0, size=(1400, 900))
display.start()

def show_video():
  mp4list = glob.glob('video/*.mp4')
  if len(mp4list) > 0:
    mp4 = mp4list[0]
    video = io.open(mp4, 'r+b').read()
    encoded = base64.b64encode(video)
    ipythondisplay.display(HTML(data='''<video alt="test" autoplay
                loop controls style="height: 400px;">
                <source src="data:video/mp4;base64,{0}" type="video/mp4" />
             </video>'''.format(encoded.decode('ascii'))))
  else:
    print("No se encuentra el video")

def wrap_env(env):
  env = RecordVideo(env, './video',  episode_trigger = lambda episode_number: True)
  return env

# %% [markdown]
# Definimos ahora los parámetros de nuestro experimento. Nótese que el número de episodios es elevado: aprender mediante *aprendizaje por refuerzo* suele llevar muchísimos intentos.

# %%
# Número de episodios
n_episodes = 2000

# Parametros de Q-Learning
alpha = 0.1
gamma = 0.99

# Parametros de epsilon-voraz
epsilon = 1.0
epsilon_min = 0.01
delta = 0.999

# Posibles bins por cada dimension del estado
bins_per_state = 16
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# Ahora iteramos durante `n_episodes` episodios sobre el entorno, aprendiendo de cada experiencia según el algoritmo Q-Learning.
#
# Iremos monitorizando las recompensas acumuladas de cada episodio, así como el promedio de recompensas acumuladas de los últimos 100 episodios (para tener una mejor estimación de la tendencia).

# %%
import gym
import numpy as np
from collections import deque

bins = np.array([
    # posición del carro
    np.linspace(-2.4, 2.4, bins_per_state),
    # velocidad del carro
    np.linspace(-3.0, 3.0, bins_per_state),
    # ángulo del poste
    np.linspace(-0.5, 0.5, bins_per_state),
    # velocidad del poste
    np.linspace(-2.0, 2.0, bins_per_state)
])

# Inicializamos el entorno con el wrapper para hacer videos
env = wrap_env(gym.make('CartPole-v1'))

# Definimos el numero de posibles acciones para crear la tabla
n_actions = env.action_space.n # (2)

# La tabla tiene 4 dimensiones para el estado y 1 para las acciones
q_table = np.zeros((bins_per_state, bins_per_state, bins_per_state, bins_per_state, n_actions))

# Variable para monitorizar el promedio de ultimos 100 episodios
last_rewards = deque(maxlen=100)

# Escribimos una función que discretiza el estado (ver np.digitize)
def discretize(cont_state):
    state = []
    for i in range(len(cont_state)):
        state.append(np.digitize(cont_state[i], bins[i])-1)
    return tuple(state)

# Bucle para el número de episodios seleccionado
for i in range(n_episodes):
    episode_reward = 0

    state = env.reset()
    state = discretize(state)

    done = False
    while not done:
        env.render()

        # Politica eps-voraz
        if np.random.uniform() < epsilon:
            action = env.action_space.sample()
        else:
            action = np.argmax(q_table[state])

        # Ejecutamos accion
        next_state, reward, done, _ = env.step(action)
        next_state = discretize(next_state)

        # Acumulamos recompensa
        episode_reward += reward

        # Actualizacion q_learning
        q_table[state][action] += alpha * (reward + gamma * np.max(q_table[next_state]) - q_table[state][action])

        # Preparamos para siguiente iteracion
        state = next_state

    # Agregamos la recompensa acumulada al histórico
    last_rewards.append(episode_reward)

    # Reportamos el rendimiento en el ultimo episodio
    print("ep.: {}, eps: {:.2f}, ret.: {}, ret. prom.: {:.1f}".format(i, epsilon, episode_reward, np.mean(last_rewards)))

    # Decaemos el epsilon para balancear la exploración-explotación
    if epsilon > epsilon_min:
        epsilon *= delta
# Out:
# ep.: 0, eps: 1.00, ret.: 9.0, ret. prom.: 9.0
# ep.: 1, eps: 1.00, ret.: 15.0, ret. prom.: 12.0
# ep.: 2, eps: 1.00, ret.: 46.0, ret. prom.: 23.3
# ep.: 3, eps: 1.00, ret.: 47.0, ret. prom.: 29.2
# ep.: 4, eps: 1.00, ret.: 12.0, ret. prom.: 25.8
# ep.: 5, eps: 1.00, ret.: 29.0, ret. prom.: 26.3
# ep.: 6, eps: 0.99, ret.: 15.0, ret. prom.: 24.7
# ep.: 7, eps: 0.99, ret.: 15.0, ret. prom.: 23.5
# ep.: 8, eps: 0.99, ret.: 12.0, ret. prom.: 22.2
# ep.: 9, eps: 0.99, ret.: 13.0, ret. prom.: 21.3
# ep.: 10, eps: 0.99, ret.: 24.0, ret. prom.: 21.5
# ep.: 11, eps: 0.99, ret.: 22.0, ret. prom.: 21.6
# ep.: 12, eps: 0.99, ret.: 42.0, ret. prom.: 23.2
# ep.: 13, eps: 0.99, ret.: 16.0, ret. prom.: 22.6
# ep.: 14, eps: 0.99, ret.: 23.0, ret. prom.: 22.7
# ep.: 15, eps: 0.99, ret.: 24.0, ret. prom.: 22.8
# ep.: 16, eps: 0.98, ret.: 21.0, ret. prom.: 22.6
# ep.: 17, eps: 0.98, ret.: 23.0, ret. prom.: 22.7
# ep.: 18, eps: 0.98, ret.: 29.0, ret. prom.: 23.0
# ep.: 19, eps: 0.98, ret.: 30.0, ret. prom.: 23.4
# ep.: 20, eps: 0.98, ret.: 10.0, ret. prom.: 22.7
# ep.: 21, eps: 0.98, ret.: 19.0, ret. prom.: 22.5
# ep.: 22, eps: 0.98, ret.: 11.0, ret. prom.: 22.0
# ep.: 23, eps: 0.98, ret.: 15.0, ret. prom.: 21.8
# ep.: 24, eps: 0.98, ret.: 15.0, ret. prom.: 21.5
# ep.: 25, eps: 0.98, ret.: 16.0, ret. prom.: 21.3
# ep.: 26, eps: 0.97, ret.: 41.0, ret. prom.: 22.0
# ep.: 27, eps: 0.97, ret.: 20.0, ret. prom.: 21.9
# ep.: 28, eps: 0.97, ret.: 16.0, ret. prom.: 21.7
# ep.: 29, eps: 0.97, ret.: 12.0, ret. prom.: 21.4
# ep.: 30, eps: 0.97, ret.: 12.0, ret. prom.: 21.1
# ep.: 31, eps: 0.97, ret.: 19.0, ret. prom.: 21.0
# ep.: 32, eps: 0.97, ret.: 13.0, ret. prom.: 20.8
# ep.: 33, eps: 0.97, ret.: 18.0, ret. prom.: 20.7
# ep.: 34, eps: 0.97, ret.: 18.0, ret. prom.: 20.6
# ep.: 35, eps: 0.97, ret.: 21.0, ret. prom.: 20.6
# ep.: 36, eps: 0.96, ret.: 21.0, ret. prom.: 20.6
# ep.: 37, eps: 0.96, ret.: 8.0, ret. prom.: 20.3
# ep.: 38, eps: 0.96, ret.: 14.0, ret. prom.: 20.2
# ep.: 39, eps: 0.96, ret.: 27.0, ret. prom.: 20.3
# ep.: 40, eps: 0.96, ret.: 19.0, ret. prom.: 20.3
# ep.: 41, eps: 0.96, ret.: 23.0, ret. prom.: 20.4
# ep.: 42, eps: 0.96, ret.: 28.0, ret. prom.: 20.5
# ep.: 43, eps: 0.96, ret.: 11.0, ret. prom.: 20.3
# ep.: 44, eps: 0.96, ret.: 21.0, ret. prom.: 20.3
# ep.: 45, eps: 0.96, ret.: 15.0, ret. prom.: 20.2
# ep.: 46, eps: 0.96, ret.: 35.0, ret. prom.: 20.5
# ep.: 47, eps: 0.95, ret.: 16.0, ret. prom.: 20.4
# ep.: 48, eps: 0.95, ret.: 19.0, ret. prom.: 20.4
# ep.: 49, eps: 0.95, ret.: 18.0, ret. prom.: 20.4
# ep.: 50, eps: 0.95, ret.: 11.0, ret. prom.: 20.2
# ep.: 51, eps: 0.95, ret.: 22.0, ret. prom.: 20.2
# ep.: 52, eps: 0.95, ret.: 17.0, ret. prom.: 20.2
# ep.: 53, eps: 0.95, ret.: 17.0, ret. prom.: 20.1
# ep.: 54, eps: 0.95, ret.: 17.0, ret. prom.: 20.0
# ep.: 55, eps: 0.95, ret.: 38.0, ret. prom.: 20.4
# ep.: 56, eps: 0.95, ret.: 31.0, ret. prom.: 20.5
# ep.: 57, eps: 0.94, ret.: 28.0, ret. prom.: 20.7
# ep.: 58, eps: 0.94, ret.: 18.0, ret. prom.: 20.6
# ep.: 59, eps: 0.94, ret.: 12.0, ret. prom.: 20.5
# ep.: 60, eps: 0.94, ret.: 13.0, ret. prom.: 20.4
# ep.: 61, eps: 0.94, ret.: 23.0, ret. prom.: 20.4
# ep.: 62, eps: 0.94, ret.: 46.0, ret. prom.: 20.8
# ep.: 63, eps: 0.94, ret.: 36.0, ret. prom.: 21.0
# ep.: 64, eps: 0.94, ret.: 43.0, ret. prom.: 21.4
# ep.: 65, eps: 0.94, ret.: 13.0, ret. prom.: 21.3
# ep.: 66, eps: 0.94, ret.: 10.0, ret. prom.: 21.1
# ep.: 67, eps: 0.94, ret.: 21.0, ret. prom.: 21.1
# ep.: 68, eps: 0.93, ret.: 16.0, ret. prom.: 21.0
# ep.: 69, eps: 0.93, ret.: 41.0, ret. prom.: 21.3
# ep.: 70, eps: 0.93, ret.: 26.0, ret. prom.: 21.4
# ep.: 71, eps: 0.93, ret.: 18.0, ret. prom.: 21.3
# ep.: 72, eps: 0.93, ret.: 16.0, ret. prom.: 21.2
# ep.: 73, eps: 0.93, ret.: 32.0, ret. prom.: 21.4
# ep.: 74, eps: 0.93, ret.: 12.0, ret. prom.: 21.3
# ep.: 75, eps: 0.93, ret.: 23.0, ret. prom.: 21.3
# ep.: 76, eps: 0.93, ret.: 25.0, ret. prom.: 21.3
# ep.: 77, eps: 0.93, ret.: 27.0, ret. prom.: 21.4
# ep.: 78, eps: 0.92, ret.: 27.0, ret. prom.: 21.5
# ep.: 79, eps: 0.92, ret.: 16.0, ret. prom.: 21.4
# ep.: 80, eps: 0.92, ret.: 20.0, ret. prom.: 21.4
# ep.: 81, eps: 0.92, ret.: 17.0, ret. prom.: 21.3
# ep.: 82, eps: 0.92, ret.: 20.0, ret. prom.: 21.3
# ep.: 83, eps: 0.92, ret.: 22.0, ret. prom.: 21.3
# ep.: 84, eps: 0.92, ret.: 15.0, ret. prom.: 21.3
# ep.: 85, eps: 0.92, ret.: 42.0, ret. prom.: 21.5
# ep.: 86, eps: 0.92, ret.: 16.0, ret. prom.: 21.4
# ep.: 87, eps: 0.92, ret.: 15.0, ret. prom.: 21.4
# ep.: 88, eps: 0.92, ret.: 18.0, ret. prom.: 21.3
# ep.: 89, eps: 0.91, ret.: 42.0, ret. prom.: 21.6
# ep.: 90, eps: 0.91, ret.: 13.0, ret. prom.: 21.5
# ep.: 91, eps: 0.91, ret.: 12.0, ret. prom.: 21.4
# ep.: 92, eps: 0.91, ret.: 19.0, ret. prom.: 21.3
# ep.: 93, eps: 0.91, ret.: 19.0, ret. prom.: 21.3
# ep.: 94, eps: 0.91, ret.: 12.0, ret. prom.: 21.2
# ep.: 95, eps: 0.91, ret.: 34.0, ret. prom.: 21.3
# ep.: 96, eps: 0.91, ret.: 16.0, ret. prom.: 21.3
# ep.: 97, eps: 0.91, ret.: 12.0, ret. prom.: 21.2
# ep.: 98, eps: 0.91, ret.: 40.0, ret. prom.: 21.4
# ep.: 99, eps: 0.91, ret.: 11.0, ret. prom.: 21.3
# ep.: 100, eps: 0.90, ret.: 9.0, ret. prom.: 21.3
# ep.: 101, eps: 0.90, ret.: 12.0, ret. prom.: 21.2
# ep.: 102, eps: 0.90, ret.: 16.0, ret. prom.: 20.9
# ep.: 103, eps: 0.90, ret.: 43.0, ret. prom.: 20.9
# ep.: 104, eps: 0.90, ret.: 37.0, ret. prom.: 21.2
# ep.: 105, eps: 0.90, ret.: 30.0, ret. prom.: 21.2
# ep.: 106, eps: 0.90, ret.: 13.0, ret. prom.: 21.1
# ep.: 107, eps: 0.90, ret.: 14.0, ret. prom.: 21.1
# ep.: 108, eps: 0.90, ret.: 61.0, ret. prom.: 21.6
# ep.: 109, eps: 0.90, ret.: 10.0, ret. prom.: 21.6
# ep.: 110, eps: 0.90, ret.: 15.0, ret. prom.: 21.5
# ep.: 111, eps: 0.89, ret.: 15.0, ret. prom.: 21.4
# ep.: 112, eps: 0.89, ret.: 21.0, ret. prom.: 21.2
# ep.: 113, eps: 0.89, ret.: 21.0, ret. prom.: 21.3
# ep.: 114, eps: 0.89, ret.: 27.0, ret. prom.: 21.3
# ep.: 115, eps: 0.89, ret.: 16.0, ret. prom.: 21.2
# ep.: 116, eps: 0.89, ret.: 14.0, ret. prom.: 21.2
# ep.: 117, eps: 0.89, ret.: 20.0, ret. prom.: 21.1
# ep.: 118, eps: 0.89, ret.: 44.0, ret. prom.: 21.3
# ep.: 119, eps: 0.89, ret.: 28.0, ret. prom.: 21.3
# ep.: 120, eps: 0.89, ret.: 18.0, ret. prom.: 21.4
# ep.: 121, eps: 0.89, ret.: 33.0, ret. prom.: 21.5
# ep.: 122, eps: 0.89, ret.: 14.0, ret. prom.: 21.5
# ep.: 123, eps: 0.88, ret.: 27.0, ret. prom.: 21.6
# ep.: 124, eps: 0.88, ret.: 14.0, ret. prom.: 21.6
# ep.: 125, eps: 0.88, ret.: 34.0, ret. prom.: 21.8
# ep.: 126, eps: 0.88, ret.: 9.0, ret. prom.: 21.5
# ep.: 127, eps: 0.88, ret.: 11.0, ret. prom.: 21.4
# ep.: 128, eps: 0.88, ret.: 80.0, ret. prom.: 22.0
# ep.: 129, eps: 0.88, ret.: 41.0, ret. prom.: 22.3
# ep.: 130, eps: 0.88, ret.: 27.0, ret. prom.: 22.5
# ep.: 131, eps: 0.88, ret.: 29.0, ret. prom.: 22.6
# ep.: 132, eps: 0.88, ret.: 25.0, ret. prom.: 22.7
# ep.: 133, eps: 0.88, ret.: 18.0, ret. prom.: 22.7
# ep.: 134, eps: 0.87, ret.: 13.0, ret. prom.: 22.6
# ep.: 135, eps: 0.87, ret.: 32.0, ret. prom.: 22.8
# ep.: 136, eps: 0.87, ret.: 24.0, ret. prom.: 22.8
# ep.: 137, eps: 0.87, ret.: 26.0, ret. prom.: 23.0
# ep.: 138, eps: 0.87, ret.: 55.0, ret. prom.: 23.4
# ep.: 139, eps: 0.87, ret.: 23.0, ret. prom.: 23.3
# ep.: 140, eps: 0.87, ret.: 16.0, ret. prom.: 23.3
# ep.: 141, eps: 0.87, ret.: 21.0, ret. prom.: 23.3
# ep.: 142, eps: 0.87, ret.: 17.0, ret. prom.: 23.2
# ep.: 143, eps: 0.87, ret.: 11.0, ret. prom.: 23.2
# ep.: 144, eps: 0.87, ret.: 17.0, ret. prom.: 23.1
# ep.: 145, eps: 0.86, ret.: 14.0, ret. prom.: 23.1
# ep.: 146, eps: 0.86, ret.: 22.0, ret. prom.: 23.0
# ep.: 147, eps: 0.86, ret.: 19.0, ret. prom.: 23.0
# ep.: 148, eps: 0.86, ret.: 11.0, ret. prom.: 22.9
# ep.: 149, eps: 0.86, ret.: 38.0, ret. prom.: 23.1
# ep.: 150, eps: 0.86, ret.: 17.0, ret. prom.: 23.2
# ep.: 151, eps: 0.86, ret.: 19.0, ret. prom.: 23.2
# ep.: 152, eps: 0.86, ret.: 26.0, ret. prom.: 23.3
# ep.: 153, eps: 0.86, ret.: 49.0, ret. prom.: 23.6
# ep.: 154, eps: 0.86, ret.: 17.0, ret. prom.: 23.6
# ep.: 155, eps: 0.86, ret.: 12.0, ret. prom.: 23.3
# ep.: 156, eps: 0.86, ret.: 35.0, ret. prom.: 23.4
# ep.: 157, eps: 0.85, ret.: 19.0, ret. prom.: 23.3
# ep.: 158, eps: 0.85, ret.: 20.0, ret. prom.: 23.3
# ep.: 159, eps: 0.85, ret.: 25.0, ret. prom.: 23.4
# ep.: 160, eps: 0.85, ret.: 10.0, ret. prom.: 23.4
# ep.: 161, eps: 0.85, ret.: 26.0, ret. prom.: 23.4
# ep.: 162, eps: 0.85, ret.: 35.0, ret. prom.: 23.3
# ep.: 163, eps: 0.85, ret.: 19.0, ret. prom.: 23.1
# ep.: 164, eps: 0.85, ret.: 38.0, ret. prom.: 23.1
# ep.: 165, eps: 0.85, ret.: 16.0, ret. prom.: 23.1
# ep.: 166, eps: 0.85, ret.: 39.0, ret. prom.: 23.4
# ep.: 167, eps: 0.85, ret.: 13.0, ret. prom.: 23.3
# ep.: 168, eps: 0.85, ret.: 20.0, ret. prom.: 23.4
# ep.: 169, eps: 0.84, ret.: 27.0, ret. prom.: 23.2
# ep.: 170, eps: 0.84, ret.: 33.0, ret. prom.: 23.3
# ep.: 171, eps: 0.84, ret.: 42.0, ret. prom.: 23.6
# ep.: 172, eps: 0.84, ret.: 21.0, ret. prom.: 23.6
# ep.: 173, eps: 0.84, ret.: 28.0, ret. prom.: 23.6
# ep.: 174, eps: 0.84, ret.: 15.0, ret. prom.: 23.6
# ep.: 175, eps: 0.84, ret.: 34.0, ret. prom.: 23.7
# ep.: 176, eps: 0.84, ret.: 10.0, ret. prom.: 23.6
# ep.: 177, eps: 0.84, ret.: 15.0, ret. prom.: 23.4
# ep.: 178, eps: 0.84, ret.: 18.0, ret. prom.: 23.3
# ep.: 179, eps: 0.84, ret.: 22.0, ret. prom.: 23.4
# ep.: 180, eps: 0.84, ret.: 32.0, ret. prom.: 23.5
# ep.: 181, eps: 0.83, ret.: 17.0, ret. prom.: 23.5
# ep.: 182, eps: 0.83, ret.: 51.0, ret. prom.: 23.8
# ep.: 183, eps: 0.83, ret.: 17.0, ret. prom.: 23.8
# ep.: 184, eps: 0.83, ret.: 30.0, ret. prom.: 23.9
# ep.: 185, eps: 0.83, ret.: 22.0, ret. prom.: 23.7
# ep.: 186, eps: 0.83, ret.: 21.0, ret. prom.: 23.8
# ep.: 187, eps: 0.83, ret.: 27.0, ret. prom.: 23.9
# ep.: 188, eps: 0.83, ret.: 12.0, ret. prom.: 23.8
# ep.: 189, eps: 0.83, ret.: 57.0, ret. prom.: 24.0
# ep.: 190, eps: 0.83, ret.: 24.0, ret. prom.: 24.1
# ep.: 191, eps: 0.83, ret.: 25.0, ret. prom.: 24.2
# ep.: 192, eps: 0.83, ret.: 30.0, ret. prom.: 24.3
# ep.: 193, eps: 0.82, ret.: 35.0, ret. prom.: 24.5
# ep.: 194, eps: 0.82, ret.: 21.0, ret. prom.: 24.6
# ep.: 195, eps: 0.82, ret.: 15.0, ret. prom.: 24.4
# ep.: 196, eps: 0.82, ret.: 45.0, ret. prom.: 24.7
# ep.: 197, eps: 0.82, ret.: 21.0, ret. prom.: 24.8
# ep.: 198, eps: 0.82, ret.: 23.0, ret. prom.: 24.6
# ep.: 199, eps: 0.82, ret.: 48.0, ret. prom.: 25.0
# ep.: 200, eps: 0.82, ret.: 16.0, ret. prom.: 25.1
# ep.: 201, eps: 0.82, ret.: 17.0, ret. prom.: 25.1
# ep.: 202, eps: 0.82, ret.: 15.0, ret. prom.: 25.1
# ep.: 203, eps: 0.82, ret.: 14.0, ret. prom.: 24.8
# ep.: 204, eps: 0.82, ret.: 56.0, ret. prom.: 25.0
# ep.: 205, eps: 0.81, ret.: 18.0, ret. prom.: 24.9
# ep.: 206, eps: 0.81, ret.: 12.0, ret. prom.: 24.9
# ep.: 207, eps: 0.81, ret.: 39.0, ret. prom.: 25.1
# ep.: 208, eps: 0.81, ret.: 15.0, ret. prom.: 24.6
# ep.: 209, eps: 0.81, ret.: 37.0, ret. prom.: 24.9
# ep.: 210, eps: 0.81, ret.: 10.0, ret. prom.: 24.9
# ep.: 211, eps: 0.81, ret.: 17.0, ret. prom.: 24.9
# ep.: 212, eps: 0.81, ret.: 46.0, ret. prom.: 25.1
# ep.: 213, eps: 0.81, ret.: 10.0, ret. prom.: 25.0
# ep.: 214, eps: 0.81, ret.: 52.0, ret. prom.: 25.3
# ep.: 215, eps: 0.81, ret.: 11.0, ret. prom.: 25.2
# ep.: 216, eps: 0.81, ret.: 19.0, ret. prom.: 25.3
# ep.: 217, eps: 0.80, ret.: 29.0, ret. prom.: 25.4
# ep.: 218, eps: 0.80, ret.: 23.0, ret. prom.: 25.2
# ep.: 219, eps: 0.80, ret.: 15.0, ret. prom.: 25.0
# ep.: 220, eps: 0.80, ret.: 16.0, ret. prom.: 25.0
# ep.: 221, eps: 0.80, ret.: 20.0, ret. prom.: 24.9
# ep.: 222, eps: 0.80, ret.: 45.0, ret. prom.: 25.2
# ep.: 223, eps: 0.80, ret.: 35.0, ret. prom.: 25.3
# ep.: 224, eps: 0.80, ret.: 19.0, ret. prom.: 25.3
# ep.: 225, eps: 0.80, ret.: 75.0, ret. prom.: 25.7
# ep.: 226, eps: 0.80, ret.: 27.0, ret. prom.: 25.9
# ep.: 227, eps: 0.80, ret.: 24.0, ret. prom.: 26.0
# ep.: 228, eps: 0.80, ret.: 16.0, ret. prom.: 25.4
# ep.: 229, eps: 0.80, ret.: 25.0, ret. prom.: 25.2
# ep.: 230, eps: 0.79, ret.: 16.0, ret. prom.: 25.1
# ep.: 231, eps: 0.79, ret.: 25.0, ret. prom.: 25.1
# ep.: 232, eps: 0.79, ret.: 13.0, ret. prom.: 25.0
# ep.: 233, eps: 0.79, ret.: 15.0, ret. prom.: 24.9
# ep.: 234, eps: 0.79, ret.: 44.0, ret. prom.: 25.2
# ep.: 235, eps: 0.79, ret.: 20.0, ret. prom.: 25.1
# ep.: 236, eps: 0.79, ret.: 23.0, ret. prom.: 25.1
# ep.: 237, eps: 0.79, ret.: 45.0, ret. prom.: 25.3
# ep.: 238, eps: 0.79, ret.: 24.0, ret. prom.: 25.0
# ep.: 239, eps: 0.79, ret.: 36.0, ret. prom.: 25.1
# ep.: 240, eps: 0.79, ret.: 29.0, ret. prom.: 25.3
# ep.: 241, eps: 0.79, ret.: 19.0, ret. prom.: 25.2
# ep.: 242, eps: 0.78, ret.: 22.0, ret. prom.: 25.3
# ep.: 243, eps: 0.78, ret.: 17.0, ret. prom.: 25.4
# ep.: 244, eps: 0.78, ret.: 17.0, ret. prom.: 25.4
# ep.: 245, eps: 0.78, ret.: 36.0, ret. prom.: 25.6
# ep.: 246, eps: 0.78, ret.: 13.0, ret. prom.: 25.5
# ep.: 247, eps: 0.78, ret.: 36.0, ret. prom.: 25.6
# ep.: 248, eps: 0.78, ret.: 19.0, ret. prom.: 25.7
# ep.: 249, eps: 0.78, ret.: 14.0, ret. prom.: 25.5
# ep.: 250, eps: 0.78, ret.: 22.0, ret. prom.: 25.5
# ep.: 251, eps: 0.78, ret.: 15.0, ret. prom.: 25.5
# ep.: 252, eps: 0.78, ret.: 15.0, ret. prom.: 25.4
# ep.: 253, eps: 0.78, ret.: 27.0, ret. prom.: 25.2
# ep.: 254, eps: 0.78, ret.: 15.0, ret. prom.: 25.1
# ep.: 255, eps: 0.77, ret.: 21.0, ret. prom.: 25.2
# ep.: 256, eps: 0.77, ret.: 30.0, ret. prom.: 25.2
# ep.: 257, eps: 0.77, ret.: 17.0, ret. prom.: 25.2
# ep.: 258, eps: 0.77, ret.: 26.0, ret. prom.: 25.2
# ep.: 259, eps: 0.77, ret.: 18.0, ret. prom.: 25.2
# ep.: 260, eps: 0.77, ret.: 10.0, ret. prom.: 25.2
# ep.: 261, eps: 0.77, ret.: 27.0, ret. prom.: 25.2
# ep.: 262, eps: 0.77, ret.: 15.0, ret. prom.: 25.0
# ep.: 263, eps: 0.77, ret.: 30.0, ret. prom.: 25.1
# ep.: 264, eps: 0.77, ret.: 13.0, ret. prom.: 24.8
# ep.: 265, eps: 0.77, ret.: 13.0, ret. prom.: 24.8
# ep.: 266, eps: 0.77, ret.: 29.0, ret. prom.: 24.7
# ep.: 267, eps: 0.77, ret.: 38.0, ret. prom.: 24.9
# ep.: 268, eps: 0.76, ret.: 17.0, ret. prom.: 24.9
# ep.: 269, eps: 0.76, ret.: 43.0, ret. prom.: 25.1
# ep.: 270, eps: 0.76, ret.: 18.0, ret. prom.: 24.9
# ep.: 271, eps: 0.76, ret.: 20.0, ret. prom.: 24.7
# ep.: 272, eps: 0.76, ret.: 23.0, ret. prom.: 24.7
# ep.: 273, eps: 0.76, ret.: 11.0, ret. prom.: 24.6
# ep.: 274, eps: 0.76, ret.: 20.0, ret. prom.: 24.6
# ep.: 275, eps: 0.76, ret.: 15.0, ret. prom.: 24.4
# ep.: 276, eps: 0.76, ret.: 28.0, ret. prom.: 24.6
# ep.: 277, eps: 0.76, ret.: 35.0, ret. prom.: 24.8
# ep.: 278, eps: 0.76, ret.: 14.0, ret. prom.: 24.8
# ep.: 279, eps: 0.76, ret.: 48.0, ret. prom.: 25.0
# ep.: 280, eps: 0.76, ret.: 26.0, ret. prom.: 25.0
# ep.: 281, eps: 0.75, ret.: 38.0, ret. prom.: 25.2
# ep.: 282, eps: 0.75, ret.: 10.0, ret. prom.: 24.8
# ep.: 283, eps: 0.75, ret.: 47.0, ret. prom.: 25.1
# ep.: 284, eps: 0.75, ret.: 45.0, ret. prom.: 25.2
# ep.: 285, eps: 0.75, ret.: 34.0, ret. prom.: 25.3
# ep.: 286, eps: 0.75, ret.: 21.0, ret. prom.: 25.3
# ep.: 287, eps: 0.75, ret.: 54.0, ret. prom.: 25.6
# ep.: 288, eps: 0.75, ret.: 12.0, ret. prom.: 25.6
# ep.: 289, eps: 0.75, ret.: 16.0, ret. prom.: 25.2
# ep.: 290, eps: 0.75, ret.: 22.0, ret. prom.: 25.2
# ep.: 291, eps: 0.75, ret.: 60.0, ret. prom.: 25.5
# ep.: 292, eps: 0.75, ret.: 32.0, ret. prom.: 25.5
# ep.: 293, eps: 0.75, ret.: 12.0, ret. prom.: 25.3
# ep.: 294, eps: 0.75, ret.: 16.0, ret. prom.: 25.3
# ep.: 295, eps: 0.74, ret.: 18.0, ret. prom.: 25.3
# ep.: 296, eps: 0.74, ret.: 12.0, ret. prom.: 25.0
# ep.: 297, eps: 0.74, ret.: 42.0, ret. prom.: 25.2
# ep.: 298, eps: 0.74, ret.: 15.0, ret. prom.: 25.1
# ep.: 299, eps: 0.74, ret.: 16.0, ret. prom.: 24.8
# ep.: 300, eps: 0.74, ret.: 32.0, ret. prom.: 24.9
# ep.: 301, eps: 0.74, ret.: 21.0, ret. prom.: 25.0
# ep.: 302, eps: 0.74, ret.: 24.0, ret. prom.: 25.1
# ep.: 303, eps: 0.74, ret.: 31.0, ret. prom.: 25.2
# ep.: 304, eps: 0.74, ret.: 10.0, ret. prom.: 24.8
# ep.: 305, eps: 0.74, ret.: 17.0, ret. prom.: 24.8
# ep.: 306, eps: 0.74, ret.: 34.0, ret. prom.: 25.0
# ep.: 307, eps: 0.74, ret.: 31.0, ret. prom.: 24.9
# ep.: 308, eps: 0.73, ret.: 16.0, ret. prom.: 24.9
# ep.: 309, eps: 0.73, ret.: 22.0, ret. prom.: 24.8
# ep.: 310, eps: 0.73, ret.: 22.0, ret. prom.: 24.9
# ep.: 311, eps: 0.73, ret.: 24.0, ret. prom.: 24.9
# ep.: 312, eps: 0.73, ret.: 21.0, ret. prom.: 24.7
# ep.: 313, eps: 0.73, ret.: 19.0, ret. prom.: 24.8
# ep.: 314, eps: 0.73, ret.: 20.0, ret. prom.: 24.5
# ep.: 315, eps: 0.73, ret.: 26.0, ret. prom.: 24.6
# ep.: 316, eps: 0.73, ret.: 28.0, ret. prom.: 24.7
# ep.: 317, eps: 0.73, ret.: 19.0, ret. prom.: 24.6
# ep.: 318, eps: 0.73, ret.: 18.0, ret. prom.: 24.6
# ep.: 319, eps: 0.73, ret.: 21.0, ret. prom.: 24.6
# ep.: 320, eps: 0.73, ret.: 35.0, ret. prom.: 24.8
# ep.: 321, eps: 0.73, ret.: 9.0, ret. prom.: 24.7
# ep.: 322, eps: 0.72, ret.: 41.0, ret. prom.: 24.7
# ep.: 323, eps: 0.72, ret.: 50.0, ret. prom.: 24.8
# ep.: 324, eps: 0.72, ret.: 32.0, ret. prom.: 24.9
# ep.: 325, eps: 0.72, ret.: 22.0, ret. prom.: 24.4
# ep.: 326, eps: 0.72, ret.: 30.0, ret. prom.: 24.4
# ep.: 327, eps: 0.72, ret.: 33.0, ret. prom.: 24.5
# ep.: 328, eps: 0.72, ret.: 19.0, ret. prom.: 24.6
# ep.: 329, eps: 0.72, ret.: 40.0, ret. prom.: 24.7
# ep.: 330, eps: 0.72, ret.: 21.0, ret. prom.: 24.8
# ep.: 331, eps: 0.72, ret.: 51.0, ret. prom.: 25.0
# ep.: 332, eps: 0.72, ret.: 77.0, ret. prom.: 25.7
# ep.: 333, eps: 0.72, ret.: 20.0, ret. prom.: 25.7
# ep.: 334, eps: 0.72, ret.: 29.0, ret. prom.: 25.6
# ep.: 335, eps: 0.72, ret.: 10.0, ret. prom.: 25.5
# ep.: 336, eps: 0.71, ret.: 19.0, ret. prom.: 25.4
# ep.: 337, eps: 0.71, ret.: 18.0, ret. prom.: 25.1
# ep.: 338, eps: 0.71, ret.: 34.0, ret. prom.: 25.2
# ep.: 339, eps: 0.71, ret.: 42.0, ret. prom.: 25.3
# ep.: 340, eps: 0.71, ret.: 26.0, ret. prom.: 25.3
# ep.: 341, eps: 0.71, ret.: 47.0, ret. prom.: 25.6
# ep.: 342, eps: 0.71, ret.: 54.0, ret. prom.: 25.9
# ep.: 343, eps: 0.71, ret.: 23.0, ret. prom.: 25.9
# ep.: 344, eps: 0.71, ret.: 68.0, ret. prom.: 26.4
# ep.: 345, eps: 0.71, ret.: 57.0, ret. prom.: 26.7
# ep.: 346, eps: 0.71, ret.: 51.0, ret. prom.: 27.0
# ep.: 347, eps: 0.71, ret.: 63.0, ret. prom.: 27.3
# ep.: 348, eps: 0.71, ret.: 33.0, ret. prom.: 27.4
# ep.: 349, eps: 0.71, ret.: 14.0, ret. prom.: 27.4
# ep.: 350, eps: 0.70, ret.: 29.0, ret. prom.: 27.5
# ep.: 351, eps: 0.70, ret.: 25.0, ret. prom.: 27.6
# ep.: 352, eps: 0.70, ret.: 97.0, ret. prom.: 28.4
# ep.: 353, eps: 0.70, ret.: 59.0, ret. prom.: 28.8
# ep.: 354, eps: 0.70, ret.: 48.0, ret. prom.: 29.1
# ep.: 355, eps: 0.70, ret.: 28.0, ret. prom.: 29.2
# ep.: 356, eps: 0.70, ret.: 23.0, ret. prom.: 29.1
# ep.: 357, eps: 0.70, ret.: 17.0, ret. prom.: 29.1
# ep.: 358, eps: 0.70, ret.: 40.0, ret. prom.: 29.2
# ep.: 359, eps: 0.70, ret.: 43.0, ret. prom.: 29.5
# ep.: 360, eps: 0.70, ret.: 35.0, ret. prom.: 29.7
# ep.: 361, eps: 0.70, ret.: 20.0, ret. prom.: 29.7
# ep.: 362, eps: 0.70, ret.: 31.0, ret. prom.: 29.8
# ep.: 363, eps: 0.70, ret.: 32.0, ret. prom.: 29.8
# ep.: 364, eps: 0.69, ret.: 27.0, ret. prom.: 30.0
# ep.: 365, eps: 0.69, ret.: 15.0, ret. prom.: 30.0
# ep.: 366, eps: 0.69, ret.: 46.0, ret. prom.: 30.2
# ep.: 367, eps: 0.69, ret.: 42.0, ret. prom.: 30.2
# ep.: 368, eps: 0.69, ret.: 38.0, ret. prom.: 30.4
# ep.: 369, eps: 0.69, ret.: 10.0, ret. prom.: 30.1
# ep.: 370, eps: 0.69, ret.: 67.0, ret. prom.: 30.6
# ep.: 371, eps: 0.69, ret.: 27.0, ret. prom.: 30.6
# ep.: 372, eps: 0.69, ret.: 24.0, ret. prom.: 30.7
# ep.: 373, eps: 0.69, ret.: 42.0, ret. prom.: 31.0
# ep.: 374, eps: 0.69, ret.: 20.0, ret. prom.: 31.0
# ep.: 375, eps: 0.69, ret.: 28.0, ret. prom.: 31.1
# ep.: 376, eps: 0.69, ret.: 21.0, ret. prom.: 31.0
# ep.: 377, eps: 0.69, ret.: 26.0, ret. prom.: 30.9
# ep.: 378, eps: 0.69, ret.: 32.0, ret. prom.: 31.1
# ep.: 379, eps: 0.68, ret.: 17.0, ret. prom.: 30.8
# ep.: 380, eps: 0.68, ret.: 35.0, ret. prom.: 30.9
# ep.: 381, eps: 0.68, ret.: 35.0, ret. prom.: 30.9
# ep.: 382, eps: 0.68, ret.: 32.0, ret. prom.: 31.1
# ep.: 383, eps: 0.68, ret.: 23.0, ret. prom.: 30.9
# ep.: 384, eps: 0.68, ret.: 63.0, ret. prom.: 31.0
# ep.: 385, eps: 0.68, ret.: 47.0, ret. prom.: 31.2
# ep.: 386, eps: 0.68, ret.: 53.0, ret. prom.: 31.5
# ep.: 387, eps: 0.68, ret.: 35.0, ret. prom.: 31.3
# ep.: 388, eps: 0.68, ret.: 60.0, ret. prom.: 31.8
# ep.: 389, eps: 0.68, ret.: 35.0, ret. prom.: 32.0
# ep.: 390, eps: 0.68, ret.: 31.0, ret. prom.: 32.0
# ep.: 391, eps: 0.68, ret.: 39.0, ret. prom.: 31.8
# ep.: 392, eps: 0.68, ret.: 16.0, ret. prom.: 31.7
# ep.: 393, eps: 0.67, ret.: 33.0, ret. prom.: 31.9
# ep.: 394, eps: 0.67, ret.: 19.0, ret. prom.: 31.9
# ep.: 395, eps: 0.67, ret.: 15.0, ret. prom.: 31.9
# ep.: 396, eps: 0.67, ret.: 58.0, ret. prom.: 32.4
# ep.: 397, eps: 0.67, ret.: 38.0, ret. prom.: 32.3
# ep.: 398, eps: 0.67, ret.: 18.0, ret. prom.: 32.3
# ep.: 399, eps: 0.67, ret.: 37.0, ret. prom.: 32.5
# ep.: 400, eps: 0.67, ret.: 31.0, ret. prom.: 32.5
# ep.: 401, eps: 0.67, ret.: 52.0, ret. prom.: 32.9
# ep.: 402, eps: 0.67, ret.: 60.0, ret. prom.: 33.2
# ep.: 403, eps: 0.67, ret.: 32.0, ret. prom.: 33.2
# ep.: 404, eps: 0.67, ret.: 24.0, ret. prom.: 33.4
# ep.: 405, eps: 0.67, ret.: 28.0, ret. prom.: 33.5
# ep.: 406, eps: 0.67, ret.: 12.0, ret. prom.: 33.2
# ep.: 407, eps: 0.67, ret.: 30.0, ret. prom.: 33.2
# ep.: 408, eps: 0.66, ret.: 55.0, ret. prom.: 33.6
# ep.: 409, eps: 0.66, ret.: 12.0, ret. prom.: 33.5
# ep.: 410, eps: 0.66, ret.: 25.0, ret. prom.: 33.6
# ep.: 411, eps: 0.66, ret.: 19.0, ret. prom.: 33.5
# ep.: 412, eps: 0.66, ret.: 76.0, ret. prom.: 34.1
# ep.: 413, eps: 0.66, ret.: 28.0, ret. prom.: 34.1
# ep.: 414, eps: 0.66, ret.: 42.0, ret. prom.: 34.4
# ep.: 415, eps: 0.66, ret.: 15.0, ret. prom.: 34.3
# ep.: 416, eps: 0.66, ret.: 18.0, ret. prom.: 34.2
# ep.: 417, eps: 0.66, ret.: 15.0, ret. prom.: 34.1
# ep.: 418, eps: 0.66, ret.: 44.0, ret. prom.: 34.4
# ep.: 419, eps: 0.66, ret.: 44.0, ret. prom.: 34.6
# ep.: 420, eps: 0.66, ret.: 35.0, ret. prom.: 34.6
# ep.: 421, eps: 0.66, ret.: 32.0, ret. prom.: 34.8
# ep.: 422, eps: 0.66, ret.: 85.0, ret. prom.: 35.3
# ep.: 423, eps: 0.65, ret.: 28.0, ret. prom.: 35.1
# ep.: 424, eps: 0.65, ret.: 54.0, ret. prom.: 35.3
# ep.: 425, eps: 0.65, ret.: 23.0, ret. prom.: 35.3
# ep.: 426, eps: 0.65, ret.: 48.0, ret. prom.: 35.5
# ep.: 427, eps: 0.65, ret.: 26.0, ret. prom.: 35.4
# ep.: 428, eps: 0.65, ret.: 12.0, ret. prom.: 35.3
# ep.: 429, eps: 0.65, ret.: 13.0, ret. prom.: 35.1
# ep.: 430, eps: 0.65, ret.: 12.0, ret. prom.: 35.0
# ep.: 431, eps: 0.65, ret.: 18.0, ret. prom.: 34.6
# ep.: 432, eps: 0.65, ret.: 36.0, ret. prom.: 34.2
# ep.: 433, eps: 0.65, ret.: 100.0, ret. prom.: 35.0
# ep.: 434, eps: 0.65, ret.: 26.0, ret. prom.: 35.0
# ep.: 435, eps: 0.65, ret.: 30.0, ret. prom.: 35.2
# ep.: 436, eps: 0.65, ret.: 20.0, ret. prom.: 35.2
# ep.: 437, eps: 0.65, ret.: 12.0, ret. prom.: 35.1
# ep.: 438, eps: 0.65, ret.: 27.0, ret. prom.: 35.1
# ep.: 439, eps: 0.64, ret.: 20.0, ret. prom.: 34.9
# ep.: 440, eps: 0.64, ret.: 52.0, ret. prom.: 35.1
# ep.: 441, eps: 0.64, ret.: 34.0, ret. prom.: 35.0
# ep.: 442, eps: 0.64, ret.: 20.0, ret. prom.: 34.6
# ep.: 443, eps: 0.64, ret.: 11.0, ret. prom.: 34.5
# ep.: 444, eps: 0.64, ret.: 44.0, ret. prom.: 34.3
# ep.: 445, eps: 0.64, ret.: 35.0, ret. prom.: 34.1
# ep.: 446, eps: 0.64, ret.: 35.0, ret. prom.: 33.9
# ep.: 447, eps: 0.64, ret.: 54.0, ret. prom.: 33.8
# ep.: 448, eps: 0.64, ret.: 48.0, ret. prom.: 34.0
# ep.: 449, eps: 0.64, ret.: 33.0, ret. prom.: 34.2
# ep.: 450, eps: 0.64, ret.: 11.0, ret. prom.: 34.0
# ep.: 451, eps: 0.64, ret.: 25.0, ret. prom.: 34.0
# ep.: 452, eps: 0.64, ret.: 18.0, ret. prom.: 33.2
# ep.: 453, eps: 0.64, ret.: 41.0, ret. prom.: 33.0
# ep.: 454, eps: 0.63, ret.: 12.0, ret. prom.: 32.6
# ep.: 455, eps: 0.63, ret.: 35.0, ret. prom.: 32.7
# ep.: 456, eps: 0.63, ret.: 25.0, ret. prom.: 32.7
# ep.: 457, eps: 0.63, ret.: 39.0, ret. prom.: 33.0
# ep.: 458, eps: 0.63, ret.: 18.0, ret. prom.: 32.7
# ep.: 459, eps: 0.63, ret.: 41.0, ret. prom.: 32.7
# ep.: 460, eps: 0.63, ret.: 18.0, ret. prom.: 32.5
# ep.: 461, eps: 0.63, ret.: 37.0, ret. prom.: 32.7
# ep.: 462, eps: 0.63, ret.: 20.0, ret. prom.: 32.6
# ep.: 463, eps: 0.63, ret.: 54.0, ret. prom.: 32.8
# ep.: 464, eps: 0.63, ret.: 65.0, ret. prom.: 33.2
# ep.: 465, eps: 0.63, ret.: 81.0, ret. prom.: 33.9
# ep.: 466, eps: 0.63, ret.: 46.0, ret. prom.: 33.9
# ep.: 467, eps: 0.63, ret.: 56.0, ret. prom.: 34.0
# ep.: 468, eps: 0.63, ret.: 73.0, ret. prom.: 34.4
# ep.: 469, eps: 0.63, ret.: 98.0, ret. prom.: 35.2
# ep.: 470, eps: 0.62, ret.: 37.0, ret. prom.: 34.9
# ep.: 471, eps: 0.62, ret.: 36.0, ret. prom.: 35.0
# ep.: 472, eps: 0.62, ret.: 12.0, ret. prom.: 34.9
# ep.: 473, eps: 0.62, ret.: 43.0, ret. prom.: 34.9
# ep.: 474, eps: 0.62, ret.: 33.0, ret. prom.: 35.0
# ep.: 475, eps: 0.62, ret.: 35.0, ret. prom.: 35.1
# ep.: 476, eps: 0.62, ret.: 35.0, ret. prom.: 35.3
# ep.: 477, eps: 0.62, ret.: 24.0, ret. prom.: 35.2
# ep.: 478, eps: 0.62, ret.: 26.0, ret. prom.: 35.2
# ep.: 479, eps: 0.62, ret.: 40.0, ret. prom.: 35.4
# ep.: 480, eps: 0.62, ret.: 59.0, ret. prom.: 35.6
# ep.: 481, eps: 0.62, ret.: 34.0, ret. prom.: 35.6
# ep.: 482, eps: 0.62, ret.: 38.0, ret. prom.: 35.7
# ep.: 483, eps: 0.62, ret.: 20.0, ret. prom.: 35.7
# ep.: 484, eps: 0.62, ret.: 75.0, ret. prom.: 35.8
# ep.: 485, eps: 0.62, ret.: 26.0, ret. prom.: 35.6
# ep.: 486, eps: 0.61, ret.: 25.0, ret. prom.: 35.3
# ep.: 487, eps: 0.61, ret.: 54.0, ret. prom.: 35.5
# ep.: 488, eps: 0.61, ret.: 52.0, ret. prom.: 35.4
# ep.: 489, eps: 0.61, ret.: 24.0, ret. prom.: 35.3
# ep.: 490, eps: 0.61, ret.: 25.0, ret. prom.: 35.2
# ep.: 491, eps: 0.61, ret.: 35.0, ret. prom.: 35.2
# ep.: 492, eps: 0.61, ret.: 24.0, ret. prom.: 35.3
# ep.: 493, eps: 0.61, ret.: 19.0, ret. prom.: 35.1
# ep.: 494, eps: 0.61, ret.: 35.0, ret. prom.: 35.3
# ep.: 495, eps: 0.61, ret.: 52.0, ret. prom.: 35.7
# ep.: 496, eps: 0.61, ret.: 98.0, ret. prom.: 36.1
# ep.: 497, eps: 0.61, ret.: 29.0, ret. prom.: 36.0
# ep.: 498, eps: 0.61, ret.: 87.0, ret. prom.: 36.7
# ep.: 499, eps: 0.61, ret.: 24.0, ret. prom.: 36.5
# ep.: 500, eps: 0.61, ret.: 20.0, ret. prom.: 36.4
# ep.: 501, eps: 0.61, ret.: 37.0, ret. prom.: 36.3
# ep.: 502, eps: 0.61, ret.: 89.0, ret. prom.: 36.6
# ep.: 503, eps: 0.60, ret.: 36.0, ret. prom.: 36.6
# ep.: 504, eps: 0.60, ret.: 40.0, ret. prom.: 36.8
# ep.: 505, eps: 0.60, ret.: 74.0, ret. prom.: 37.2
# ep.: 506, eps: 0.60, ret.: 53.0, ret. prom.: 37.6
# ep.: 507, eps: 0.60, ret.: 22.0, ret. prom.: 37.6
# ep.: 508, eps: 0.60, ret.: 24.0, ret. prom.: 37.2
# ep.: 509, eps: 0.60, ret.: 49.0, ret. prom.: 37.6
# ep.: 510, eps: 0.60, ret.: 50.0, ret. prom.: 37.9
# ep.: 511, eps: 0.60, ret.: 49.0, ret. prom.: 38.2
# ep.: 512, eps: 0.60, ret.: 27.0, ret. prom.: 37.7
# ep.: 513, eps: 0.60, ret.: 38.0, ret. prom.: 37.8
# ep.: 514, eps: 0.60, ret.: 20.0, ret. prom.: 37.6
# ep.: 515, eps: 0.60, ret.: 42.0, ret. prom.: 37.8
# ep.: 516, eps: 0.60, ret.: 120.0, ret. prom.: 38.9
# ep.: 517, eps: 0.60, ret.: 26.0, ret. prom.: 39.0
# ep.: 518, eps: 0.60, ret.: 33.0, ret. prom.: 38.9
# ep.: 519, eps: 0.59, ret.: 42.0, ret. prom.: 38.8
# ep.: 520, eps: 0.59, ret.: 44.0, ret. prom.: 38.9
# ep.: 521, eps: 0.59, ret.: 62.0, ret. prom.: 39.2
# ep.: 522, eps: 0.59, ret.: 87.0, ret. prom.: 39.2
# ep.: 523, eps: 0.59, ret.: 53.0, ret. prom.: 39.5
# ep.: 524, eps: 0.59, ret.: 57.0, ret. prom.: 39.5
# ep.: 525, eps: 0.59, ret.: 55.0, ret. prom.: 39.8
# ep.: 526, eps: 0.59, ret.: 53.0, ret. prom.: 39.9
# ep.: 527, eps: 0.59, ret.: 57.0, ret. prom.: 40.2
# ep.: 528, eps: 0.59, ret.: 55.0, ret. prom.: 40.6
# ep.: 529, eps: 0.59, ret.: 20.0, ret. prom.: 40.7
# ep.: 530, eps: 0.59, ret.: 19.0, ret. prom.: 40.8
# ep.: 531, eps: 0.59, ret.: 31.0, ret. prom.: 40.9
# ep.: 532, eps: 0.59, ret.: 37.0, ret. prom.: 40.9
# ep.: 533, eps: 0.59, ret.: 108.0, ret. prom.: 41.0
# ep.: 534, eps: 0.59, ret.: 17.0, ret. prom.: 40.9
# ep.: 535, eps: 0.59, ret.: 24.0, ret. prom.: 40.8
# ep.: 536, eps: 0.58, ret.: 31.0, ret. prom.: 41.0
# ep.: 537, eps: 0.58, ret.: 12.0, ret. prom.: 41.0
# ep.: 538, eps: 0.58, ret.: 49.0, ret. prom.: 41.2
# ep.: 539, eps: 0.58, ret.: 18.0, ret. prom.: 41.1
# ep.: 540, eps: 0.58, ret.: 60.0, ret. prom.: 41.2
# ep.: 541, eps: 0.58, ret.: 47.0, ret. prom.: 41.4
# ep.: 542, eps: 0.58, ret.: 38.0, ret. prom.: 41.5
# ep.: 543, eps: 0.58, ret.: 20.0, ret. prom.: 41.6
# ep.: 544, eps: 0.58, ret.: 27.0, ret. prom.: 41.5
# ep.: 545, eps: 0.58, ret.: 87.0, ret. prom.: 42.0
# ep.: 546, eps: 0.58, ret.: 42.0, ret. prom.: 42.0
# ep.: 547, eps: 0.58, ret.: 21.0, ret. prom.: 41.7
# ep.: 548, eps: 0.58, ret.: 29.0, ret. prom.: 41.5
# ep.: 549, eps: 0.58, ret.: 56.0, ret. prom.: 41.8
# ep.: 550, eps: 0.58, ret.: 102.0, ret. prom.: 42.7
# ep.: 551, eps: 0.58, ret.: 29.0, ret. prom.: 42.7
# ep.: 552, eps: 0.58, ret.: 16.0, ret. prom.: 42.7
# ep.: 553, eps: 0.58, ret.: 53.0, ret. prom.: 42.8
# ep.: 554, eps: 0.57, ret.: 80.0, ret. prom.: 43.5
# ep.: 555, eps: 0.57, ret.: 77.0, ret. prom.: 43.9
# ep.: 556, eps: 0.57, ret.: 36.0, ret. prom.: 44.0
# ep.: 557, eps: 0.57, ret.: 75.0, ret. prom.: 44.4
# ep.: 558, eps: 0.57, ret.: 26.0, ret. prom.: 44.5
# ep.: 559, eps: 0.57, ret.: 24.0, ret. prom.: 44.3
# ep.: 560, eps: 0.57, ret.: 40.0, ret. prom.: 44.5
# ep.: 561, eps: 0.57, ret.: 24.0, ret. prom.: 44.4
# ep.: 562, eps: 0.57, ret.: 38.0, ret. prom.: 44.6
# ep.: 563, eps: 0.57, ret.: 74.0, ret. prom.: 44.8
# ep.: 564, eps: 0.57, ret.: 69.0, ret. prom.: 44.8
# ep.: 565, eps: 0.57, ret.: 20.0, ret. prom.: 44.2
# ep.: 566, eps: 0.57, ret.: 28.0, ret. prom.: 44.0
# ep.: 567, eps: 0.57, ret.: 55.0, ret. prom.: 44.0
# ep.: 568, eps: 0.57, ret.: 48.0, ret. prom.: 43.8
# ep.: 569, eps: 0.57, ret.: 75.0, ret. prom.: 43.5
# ep.: 570, eps: 0.57, ret.: 59.0, ret. prom.: 43.7
# ep.: 571, eps: 0.56, ret.: 50.0, ret. prom.: 43.9
# ep.: 572, eps: 0.56, ret.: 49.0, ret. prom.: 44.2
# ep.: 573, eps: 0.56, ret.: 106.0, ret. prom.: 44.9
# ep.: 574, eps: 0.56, ret.: 53.0, ret. prom.: 45.1
# ep.: 575, eps: 0.56, ret.: 9.0, ret. prom.: 44.8
# ep.: 576, eps: 0.56, ret.: 69.0, ret. prom.: 45.2
# ep.: 577, eps: 0.56, ret.: 107.0, ret. prom.: 46.0
# ep.: 578, eps: 0.56, ret.: 76.0, ret. prom.: 46.5
# ep.: 579, eps: 0.56, ret.: 16.0, ret. prom.: 46.2
# ep.: 580, eps: 0.56, ret.: 63.0, ret. prom.: 46.3
# ep.: 581, eps: 0.56, ret.: 92.0, ret. prom.: 46.9
# ep.: 582, eps: 0.56, ret.: 48.0, ret. prom.: 47.0
# ep.: 583, eps: 0.56, ret.: 27.0, ret. prom.: 47.0
# ep.: 584, eps: 0.56, ret.: 61.0, ret. prom.: 46.9
# ep.: 585, eps: 0.56, ret.: 55.0, ret. prom.: 47.2
# ep.: 586, eps: 0.56, ret.: 67.0, ret. prom.: 47.6
# ep.: 587, eps: 0.56, ret.: 95.0, ret. prom.: 48.0
# ep.: 588, eps: 0.56, ret.: 18.0, ret. prom.: 47.7
# ep.: 589, eps: 0.55, ret.: 17.0, ret. prom.: 47.6
# ep.: 590, eps: 0.55, ret.: 32.0, ret. prom.: 47.7
# ep.: 591, eps: 0.55, ret.: 55.0, ret. prom.: 47.9
# ep.: 592, eps: 0.55, ret.: 132.0, ret. prom.: 49.0
# ep.: 593, eps: 0.55, ret.: 22.0, ret. prom.: 49.0
# ep.: 594, eps: 0.55, ret.: 58.0, ret. prom.: 49.2
# ep.: 595, eps: 0.55, ret.: 63.0, ret. prom.: 49.3
# ep.: 596, eps: 0.55, ret.: 40.0, ret. prom.: 48.8
# ep.: 597, eps: 0.55, ret.: 88.0, ret. prom.: 49.3
# ep.: 598, eps: 0.55, ret.: 38.0, ret. prom.: 48.9
# ep.: 599, eps: 0.55, ret.: 144.0, ret. prom.: 50.0
# ep.: 600, eps: 0.55, ret.: 55.0, ret. prom.: 50.4
# ep.: 601, eps: 0.55, ret.: 37.0, ret. prom.: 50.4
# ep.: 602, eps: 0.55, ret.: 88.0, ret. prom.: 50.4
# ep.: 603, eps: 0.55, ret.: 47.0, ret. prom.: 50.5
# ep.: 604, eps: 0.55, ret.: 22.0, ret. prom.: 50.3
# ep.: 605, eps: 0.55, ret.: 67.0, ret. prom.: 50.2
# ep.: 606, eps: 0.55, ret.: 23.0, ret. prom.: 50.0
# ep.: 607, eps: 0.54, ret.: 56.0, ret. prom.: 50.3
# ep.: 608, eps: 0.54, ret.: 32.0, ret. prom.: 50.4
# ep.: 609, eps: 0.54, ret.: 18.0, ret. prom.: 50.1
# ep.: 610, eps: 0.54, ret.: 23.0, ret. prom.: 49.8
# ep.: 611, eps: 0.54, ret.: 24.0, ret. prom.: 49.5
# ep.: 612, eps: 0.54, ret.: 27.0, ret. prom.: 49.5
# ep.: 613, eps: 0.54, ret.: 55.0, ret. prom.: 49.7
# ep.: 614, eps: 0.54, ret.: 90.0, ret. prom.: 50.4
# ep.: 615, eps: 0.54, ret.: 77.0, ret. prom.: 50.8
# ep.: 616, eps: 0.54, ret.: 27.0, ret. prom.: 49.8
# ep.: 617, eps: 0.54, ret.: 83.0, ret. prom.: 50.4
# ep.: 618, eps: 0.54, ret.: 76.0, ret. prom.: 50.8
# ep.: 619, eps: 0.54, ret.: 53.0, ret. prom.: 50.9
# ep.: 620, eps: 0.54, ret.: 199.0, ret. prom.: 52.5
# ep.: 621, eps: 0.54, ret.: 73.0, ret. prom.: 52.6
# ep.: 622, eps: 0.54, ret.: 47.0, ret. prom.: 52.2
# ep.: 623, eps: 0.54, ret.: 47.0, ret. prom.: 52.1
# ep.: 624, eps: 0.54, ret.: 72.0, ret. prom.: 52.3
# ep.: 625, eps: 0.54, ret.: 44.0, ret. prom.: 52.2
# ep.: 626, eps: 0.53, ret.: 82.0, ret. prom.: 52.5
# ep.: 627, eps: 0.53, ret.: 27.0, ret. prom.: 52.2
# ep.: 628, eps: 0.53, ret.: 110.0, ret. prom.: 52.7
# ep.: 629, eps: 0.53, ret.: 16.0, ret. prom.: 52.7
# ep.: 630, eps: 0.53, ret.: 46.0, ret. prom.: 53.0
# ep.: 631, eps: 0.53, ret.: 57.0, ret. prom.: 53.2
# ep.: 632, eps: 0.53, ret.: 135.0, ret. prom.: 54.2
# ep.: 633, eps: 0.53, ret.: 71.0, ret. prom.: 53.8
# ep.: 634, eps: 0.53, ret.: 88.0, ret. prom.: 54.5
# ep.: 635, eps: 0.53, ret.: 88.0, ret. prom.: 55.2
# ep.: 636, eps: 0.53, ret.: 56.0, ret. prom.: 55.4
# ep.: 637, eps: 0.53, ret.: 22.0, ret. prom.: 55.5
# ep.: 638, eps: 0.53, ret.: 46.0, ret. prom.: 55.5
# ep.: 639, eps: 0.53, ret.: 48.0, ret. prom.: 55.8
# ep.: 640, eps: 0.53, ret.: 39.0, ret. prom.: 55.6
# ep.: 641, eps: 0.53, ret.: 51.0, ret. prom.: 55.6
# ep.: 642, eps: 0.53, ret.: 39.0, ret. prom.: 55.6
# ep.: 643, eps: 0.53, ret.: 40.0, ret. prom.: 55.8
# ep.: 644, eps: 0.53, ret.: 25.0, ret. prom.: 55.8
# ep.: 645, eps: 0.52, ret.: 49.0, ret. prom.: 55.4
# ep.: 646, eps: 0.52, ret.: 63.0, ret. prom.: 55.6
# ep.: 647, eps: 0.52, ret.: 45.0, ret. prom.: 55.9
# ep.: 648, eps: 0.52, ret.: 70.0, ret. prom.: 56.3
# ep.: 649, eps: 0.52, ret.: 48.0, ret. prom.: 56.2
# ep.: 650, eps: 0.52, ret.: 85.0, ret. prom.: 56.0
# ep.: 651, eps: 0.52, ret.: 33.0, ret. prom.: 56.1
# ep.: 652, eps: 0.52, ret.: 60.0, ret. prom.: 56.5
# ep.: 653, eps: 0.52, ret.: 26.0, ret. prom.: 56.2
# ep.: 654, eps: 0.52, ret.: 45.0, ret. prom.: 55.9
# ep.: 655, eps: 0.52, ret.: 102.0, ret. prom.: 56.1
# ep.: 656, eps: 0.52, ret.: 40.0, ret. prom.: 56.2
# ep.: 657, eps: 0.52, ret.: 108.0, ret. prom.: 56.5
# ep.: 658, eps: 0.52, ret.: 28.0, ret. prom.: 56.5
# ep.: 659, eps: 0.52, ret.: 24.0, ret. prom.: 56.5
# ep.: 660, eps: 0.52, ret.: 14.0, ret. prom.: 56.3
# ep.: 661, eps: 0.52, ret.: 120.0, ret. prom.: 57.2
# ep.: 662, eps: 0.52, ret.: 64.0, ret. prom.: 57.5
# ep.: 663, eps: 0.52, ret.: 46.0, ret. prom.: 57.2
# ep.: 664, eps: 0.51, ret.: 30.0, ret. prom.: 56.8
# ep.: 665, eps: 0.51, ret.: 39.0, ret. prom.: 57.0
# ep.: 666, eps: 0.51, ret.: 63.0, ret. prom.: 57.4
# ep.: 667, eps: 0.51, ret.: 40.0, ret. prom.: 57.2
# ep.: 668, eps: 0.51, ret.: 37.0, ret. prom.: 57.1
# ep.: 669, eps: 0.51, ret.: 50.0, ret. prom.: 56.9
# ep.: 670, eps: 0.51, ret.: 68.0, ret. prom.: 57.0
# ep.: 671, eps: 0.51, ret.: 15.0, ret. prom.: 56.6
# ep.: 672, eps: 0.51, ret.: 33.0, ret. prom.: 56.4
# ep.: 673, eps: 0.51, ret.: 53.0, ret. prom.: 55.9
# ep.: 674, eps: 0.51, ret.: 25.0, ret. prom.: 55.6
# ep.: 675, eps: 0.51, ret.: 44.0, ret. prom.: 56.0
# ep.: 676, eps: 0.51, ret.: 34.0, ret. prom.: 55.6
# ep.: 677, eps: 0.51, ret.: 73.0, ret. prom.: 55.3
# ep.: 678, eps: 0.51, ret.: 24.0, ret. prom.: 54.8
# ep.: 679, eps: 0.51, ret.: 23.0, ret. prom.: 54.8
# ep.: 680, eps: 0.51, ret.: 49.0, ret. prom.: 54.7
# ep.: 681, eps: 0.51, ret.: 118.0, ret. prom.: 55.0
# ep.: 682, eps: 0.51, ret.: 60.0, ret. prom.: 55.1
# ep.: 683, eps: 0.50, ret.: 93.0, ret. prom.: 55.7
# ep.: 684, eps: 0.50, ret.: 45.0, ret. prom.: 55.6
# ep.: 685, eps: 0.50, ret.: 62.0, ret. prom.: 55.6
# ep.: 686, eps: 0.50, ret.: 41.0, ret. prom.: 55.4
# ep.: 687, eps: 0.50, ret.: 84.0, ret. prom.: 55.3
# ep.: 688, eps: 0.50, ret.: 47.0, ret. prom.: 55.6
# ep.: 689, eps: 0.50, ret.: 56.0, ret. prom.: 56.0
# ep.: 690, eps: 0.50, ret.: 62.0, ret. prom.: 56.3
# ep.: 691, eps: 0.50, ret.: 33.0, ret. prom.: 56.0
# ep.: 692, eps: 0.50, ret.: 23.0, ret. prom.: 55.0
# ep.: 693, eps: 0.50, ret.: 82.0, ret. prom.: 55.5
# ep.: 694, eps: 0.50, ret.: 61.0, ret. prom.: 55.6
# ep.: 695, eps: 0.50, ret.: 16.0, ret. prom.: 55.1
# ep.: 696, eps: 0.50, ret.: 126.0, ret. prom.: 56.0
# ep.: 697, eps: 0.50, ret.: 59.0, ret. prom.: 55.7
# ep.: 698, eps: 0.50, ret.: 93.0, ret. prom.: 56.2
# ep.: 699, eps: 0.50, ret.: 118.0, ret. prom.: 56.0
# ep.: 700, eps: 0.50, ret.: 29.0, ret. prom.: 55.7
# ep.: 701, eps: 0.50, ret.: 14.0, ret. prom.: 55.5
# ep.: 702, eps: 0.50, ret.: 30.0, ret. prom.: 54.9
# ep.: 703, eps: 0.49, ret.: 24.0, ret. prom.: 54.7
# ep.: 704, eps: 0.49, ret.: 47.0, ret. prom.: 54.9
# ep.: 705, eps: 0.49, ret.: 49.0, ret. prom.: 54.7
# ep.: 706, eps: 0.49, ret.: 45.0, ret. prom.: 55.0
# ep.: 707, eps: 0.49, ret.: 93.0, ret. prom.: 55.3
# ep.: 708, eps: 0.49, ret.: 52.0, ret. prom.: 55.5
# ep.: 709, eps: 0.49, ret.: 66.0, ret. prom.: 56.0
# ep.: 710, eps: 0.49, ret.: 33.0, ret. prom.: 56.1
# ep.: 711, eps: 0.49, ret.: 30.0, ret. prom.: 56.2
# ep.: 712, eps: 0.49, ret.: 17.0, ret. prom.: 56.1
# ep.: 713, eps: 0.49, ret.: 70.0, ret. prom.: 56.2
# ep.: 714, eps: 0.49, ret.: 53.0, ret. prom.: 55.9
# ep.: 715, eps: 0.49, ret.: 48.0, ret. prom.: 55.6
# ep.: 716, eps: 0.49, ret.: 34.0, ret. prom.: 55.6
# ep.: 717, eps: 0.49, ret.: 29.0, ret. prom.: 55.1
# ep.: 718, eps: 0.49, ret.: 32.0, ret. prom.: 54.6
# ep.: 719, eps: 0.49, ret.: 43.0, ret. prom.: 54.5
# ep.: 720, eps: 0.49, ret.: 45.0, ret. prom.: 53.0
# ep.: 721, eps: 0.49, ret.: 79.0, ret. prom.: 53.1
# ep.: 722, eps: 0.49, ret.: 43.0, ret. prom.: 53.0
# ep.: 723, eps: 0.49, ret.: 74.0, ret. prom.: 53.3
# ep.: 724, eps: 0.48, ret.: 38.0, ret. prom.: 53.0
# ep.: 725, eps: 0.48, ret.: 83.0, ret. prom.: 53.4
# ep.: 726, eps: 0.48, ret.: 92.0, ret. prom.: 53.5
# ep.: 727, eps: 0.48, ret.: 46.0, ret. prom.: 53.6
# ep.: 728, eps: 0.48, ret.: 37.0, ret. prom.: 52.9
# ep.: 729, eps: 0.48, ret.: 71.0, ret. prom.: 53.5
# ep.: 730, eps: 0.48, ret.: 42.0, ret. prom.: 53.4
# ep.: 731, eps: 0.48, ret.: 157.0, ret. prom.: 54.4
# ep.: 732, eps: 0.48, ret.: 69.0, ret. prom.: 53.8
# ep.: 733, eps: 0.48, ret.: 55.0, ret. prom.: 53.6
# ep.: 734, eps: 0.48, ret.: 103.0, ret. prom.: 53.8
# ep.: 735, eps: 0.48, ret.: 59.0, ret. prom.: 53.5
# ep.: 736, eps: 0.48, ret.: 33.0, ret. prom.: 53.2
# ep.: 737, eps: 0.48, ret.: 59.0, ret. prom.: 53.6
# ep.: 738, eps: 0.48, ret.: 44.0, ret. prom.: 53.6
# ep.: 739, eps: 0.48, ret.: 77.0, ret. prom.: 53.9
# ep.: 740, eps: 0.48, ret.: 83.0, ret. prom.: 54.3
# ep.: 741, eps: 0.48, ret.: 55.0, ret. prom.: 54.4
# ep.: 742, eps: 0.48, ret.: 68.0, ret. prom.: 54.6
# ep.: 743, eps: 0.48, ret.: 27.0, ret. prom.: 54.5
# ep.: 744, eps: 0.48, ret.: 87.0, ret. prom.: 55.1
# ep.: 745, eps: 0.47, ret.: 51.0, ret. prom.: 55.1
# ep.: 746, eps: 0.47, ret.: 114.0, ret. prom.: 55.7
# ep.: 747, eps: 0.47, ret.: 57.0, ret. prom.: 55.8
# ep.: 748, eps: 0.47, ret.: 17.0, ret. prom.: 55.2
# ep.: 749, eps: 0.47, ret.: 67.0, ret. prom.: 55.4
# ep.: 750, eps: 0.47, ret.: 85.0, ret. prom.: 55.4
# ep.: 751, eps: 0.47, ret.: 61.0, ret. prom.: 55.7
# ep.: 752, eps: 0.47, ret.: 25.0, ret. prom.: 55.4
# ep.: 753, eps: 0.47, ret.: 67.0, ret. prom.: 55.8
# ep.: 754, eps: 0.47, ret.: 27.0, ret. prom.: 55.6
# ep.: 755, eps: 0.47, ret.: 58.0, ret. prom.: 55.2
# ep.: 756, eps: 0.47, ret.: 18.0, ret. prom.: 54.9
# ep.: 757, eps: 0.47, ret.: 24.0, ret. prom.: 54.1
# ep.: 758, eps: 0.47, ret.: 73.0, ret. prom.: 54.5
# ep.: 759, eps: 0.47, ret.: 18.0, ret. prom.: 54.5
# ep.: 760, eps: 0.47, ret.: 58.0, ret. prom.: 54.9
# ep.: 761, eps: 0.47, ret.: 72.0, ret. prom.: 54.5
# ep.: 762, eps: 0.47, ret.: 89.0, ret. prom.: 54.7
# ep.: 763, eps: 0.47, ret.: 49.0, ret. prom.: 54.7
# ep.: 764, eps: 0.47, ret.: 76.0, ret. prom.: 55.2
# ep.: 765, eps: 0.47, ret.: 31.0, ret. prom.: 55.1
# ep.: 766, eps: 0.46, ret.: 13.0, ret. prom.: 54.6
# ep.: 767, eps: 0.46, ret.: 59.0, ret. prom.: 54.8
# ep.: 768, eps: 0.46, ret.: 55.0, ret. prom.: 55.0
# ep.: 769, eps: 0.46, ret.: 55.0, ret. prom.: 55.0
# ep.: 770, eps: 0.46, ret.: 26.0, ret. prom.: 54.6
# ep.: 771, eps: 0.46, ret.: 19.0, ret. prom.: 54.6
# ep.: 772, eps: 0.46, ret.: 30.0, ret. prom.: 54.6
# ep.: 773, eps: 0.46, ret.: 35.0, ret. prom.: 54.4
# ep.: 774, eps: 0.46, ret.: 51.0, ret. prom.: 54.7
# ep.: 775, eps: 0.46, ret.: 41.0, ret. prom.: 54.7
# ep.: 776, eps: 0.46, ret.: 40.0, ret. prom.: 54.7
# ep.: 777, eps: 0.46, ret.: 109.0, ret. prom.: 55.1
# ep.: 778, eps: 0.46, ret.: 43.0, ret. prom.: 55.3
# ep.: 779, eps: 0.46, ret.: 37.0, ret. prom.: 55.4
# ep.: 780, eps: 0.46, ret.: 26.0, ret. prom.: 55.2
# ep.: 781, eps: 0.46, ret.: 29.0, ret. prom.: 54.3
# ep.: 782, eps: 0.46, ret.: 52.0, ret. prom.: 54.2
# ep.: 783, eps: 0.46, ret.: 44.0, ret. prom.: 53.7
# ep.: 784, eps: 0.46, ret.: 19.0, ret. prom.: 53.5
# ep.: 785, eps: 0.46, ret.: 35.0, ret. prom.: 53.2
# ep.: 786, eps: 0.46, ret.: 64.0, ret. prom.: 53.4
# ep.: 787, eps: 0.46, ret.: 77.0, ret. prom.: 53.4
# ep.: 788, eps: 0.45, ret.: 22.0, ret. prom.: 53.1
# ep.: 789, eps: 0.45, ret.: 42.0, ret. prom.: 53.0
# ep.: 790, eps: 0.45, ret.: 32.0, ret. prom.: 52.7
# ep.: 791, eps: 0.45, ret.: 48.0, ret. prom.: 52.8
# ep.: 792, eps: 0.45, ret.: 39.0, ret. prom.: 53.0
# ep.: 793, eps: 0.45, ret.: 117.0, ret. prom.: 53.3
# ep.: 794, eps: 0.45, ret.: 59.0, ret. prom.: 53.3
# ep.: 795, eps: 0.45, ret.: 23.0, ret. prom.: 53.4
# ep.: 796, eps: 0.45, ret.: 14.0, ret. prom.: 52.3
# ep.: 797, eps: 0.45, ret.: 56.0, ret. prom.: 52.2
# ep.: 798, eps: 0.45, ret.: 29.0, ret. prom.: 51.6
# ep.: 799, eps: 0.45, ret.: 63.0, ret. prom.: 51.0
# ep.: 800, eps: 0.45, ret.: 47.0, ret. prom.: 51.2
# ep.: 801, eps: 0.45, ret.: 89.0, ret. prom.: 52.0
# ep.: 802, eps: 0.45, ret.: 216.0, ret. prom.: 53.8
# ep.: 803, eps: 0.45, ret.: 20.0, ret. prom.: 53.8
# ep.: 804, eps: 0.45, ret.: 87.0, ret. prom.: 54.2
# ep.: 805, eps: 0.45, ret.: 29.0, ret. prom.: 54.0
# ep.: 806, eps: 0.45, ret.: 14.0, ret. prom.: 53.7
# ep.: 807, eps: 0.45, ret.: 35.0, ret. prom.: 53.1
# ep.: 808, eps: 0.45, ret.: 42.0, ret. prom.: 53.0
# ep.: 809, eps: 0.45, ret.: 103.0, ret. prom.: 53.4
# ep.: 810, eps: 0.44, ret.: 25.0, ret. prom.: 53.3
# ep.: 811, eps: 0.44, ret.: 78.0, ret. prom.: 53.8
# ep.: 812, eps: 0.44, ret.: 82.0, ret. prom.: 54.4
# ep.: 813, eps: 0.44, ret.: 130.0, ret. prom.: 55.0
# ep.: 814, eps: 0.44, ret.: 50.0, ret. prom.: 55.0
# ep.: 815, eps: 0.44, ret.: 98.0, ret. prom.: 55.5
# ep.: 816, eps: 0.44, ret.: 31.0, ret. prom.: 55.5
# ep.: 817, eps: 0.44, ret.: 55.0, ret. prom.: 55.7
# ep.: 818, eps: 0.44, ret.: 39.0, ret. prom.: 55.8
# ep.: 819, eps: 0.44, ret.: 91.0, ret. prom.: 56.3
# ep.: 820, eps: 0.44, ret.: 50.0, ret. prom.: 56.3
# ep.: 821, eps: 0.44, ret.: 36.0, ret. prom.: 55.9
# ep.: 822, eps: 0.44, ret.: 60.0, ret. prom.: 56.1
# ep.: 823, eps: 0.44, ret.: 106.0, ret. prom.: 56.4
# ep.: 824, eps: 0.44, ret.: 137.0, ret. prom.: 57.4
# ep.: 825, eps: 0.44, ret.: 123.0, ret. prom.: 57.8
# ep.: 826, eps: 0.44, ret.: 69.0, ret. prom.: 57.5
# ep.: 827, eps: 0.44, ret.: 91.0, ret. prom.: 58.0
# ep.: 828, eps: 0.44, ret.: 73.0, ret. prom.: 58.4
# ep.: 829, eps: 0.44, ret.: 13.0, ret. prom.: 57.8
# ep.: 830, eps: 0.44, ret.: 69.0, ret. prom.: 58.0
# ep.: 831, eps: 0.44, ret.: 40.0, ret. prom.: 56.9
# ep.: 832, eps: 0.43, ret.: 59.0, ret. prom.: 56.8
# ep.: 833, eps: 0.43, ret.: 118.0, ret. prom.: 57.4
# ep.: 834, eps: 0.43, ret.: 79.0, ret. prom.: 57.2
# ep.: 835, eps: 0.43, ret.: 57.0, ret. prom.: 57.1
# ep.: 836, eps: 0.43, ret.: 34.0, ret. prom.: 57.1
# ep.: 837, eps: 0.43, ret.: 35.0, ret. prom.: 56.9
# ep.: 838, eps: 0.43, ret.: 13.0, ret. prom.: 56.6
# ep.: 839, eps: 0.43, ret.: 103.0, ret. prom.: 56.9
# ep.: 840, eps: 0.43, ret.: 26.0, ret. prom.: 56.3
# ep.: 841, eps: 0.43, ret.: 29.0, ret. prom.: 56.0
# ep.: 842, eps: 0.43, ret.: 85.0, ret. prom.: 56.2
# ep.: 843, eps: 0.43, ret.: 113.0, ret. prom.: 57.1
# ep.: 844, eps: 0.43, ret.: 57.0, ret. prom.: 56.8
# ep.: 845, eps: 0.43, ret.: 21.0, ret. prom.: 56.5
# ep.: 846, eps: 0.43, ret.: 57.0, ret. prom.: 55.9
# ep.: 847, eps: 0.43, ret.: 27.0, ret. prom.: 55.6
# ep.: 848, eps: 0.43, ret.: 88.0, ret. prom.: 56.3
# ep.: 849, eps: 0.43, ret.: 69.0, ret. prom.: 56.3
# ep.: 850, eps: 0.43, ret.: 13.0, ret. prom.: 55.6
# ep.: 851, eps: 0.43, ret.: 115.0, ret. prom.: 56.1
# ep.: 852, eps: 0.43, ret.: 27.0, ret. prom.: 56.2
# ep.: 853, eps: 0.43, ret.: 85.0, ret. prom.: 56.3
# ep.: 854, eps: 0.43, ret.: 44.0, ret. prom.: 56.5
# ep.: 855, eps: 0.43, ret.: 156.0, ret. prom.: 57.5
# ep.: 856, eps: 0.42, ret.: 74.0, ret. prom.: 58.0
# ep.: 857, eps: 0.42, ret.: 106.0, ret. prom.: 58.9
# ep.: 858, eps: 0.42, ret.: 26.0, ret. prom.: 58.4
# ep.: 859, eps: 0.42, ret.: 31.0, ret. prom.: 58.5
# ep.: 860, eps: 0.42, ret.: 93.0, ret. prom.: 58.9
# ep.: 861, eps: 0.42, ret.: 27.0, ret. prom.: 58.4
# ep.: 862, eps: 0.42, ret.: 91.0, ret. prom.: 58.5
# ep.: 863, eps: 0.42, ret.: 23.0, ret. prom.: 58.2
# ep.: 864, eps: 0.42, ret.: 28.0, ret. prom.: 57.7
# ep.: 865, eps: 0.42, ret.: 96.0, ret. prom.: 58.4
# ep.: 866, eps: 0.42, ret.: 121.0, ret. prom.: 59.4
# ep.: 867, eps: 0.42, ret.: 74.0, ret. prom.: 59.6
# ep.: 868, eps: 0.42, ret.: 66.0, ret. prom.: 59.7
# ep.: 869, eps: 0.42, ret.: 34.0, ret. prom.: 59.5
# ep.: 870, eps: 0.42, ret.: 32.0, ret. prom.: 59.5
# ep.: 871, eps: 0.42, ret.: 54.0, ret. prom.: 59.9
# ep.: 872, eps: 0.42, ret.: 108.0, ret. prom.: 60.7
# ep.: 873, eps: 0.42, ret.: 70.0, ret. prom.: 61.0
# ep.: 874, eps: 0.42, ret.: 94.0, ret. prom.: 61.5
# ep.: 875, eps: 0.42, ret.: 29.0, ret. prom.: 61.3
# ep.: 876, eps: 0.42, ret.: 12.0, ret. prom.: 61.1
# ep.: 877, eps: 0.42, ret.: 28.0, ret. prom.: 60.2
# ep.: 878, eps: 0.42, ret.: 57.0, ret. prom.: 60.4
# ep.: 879, eps: 0.42, ret.: 27.0, ret. prom.: 60.3
# ep.: 880, eps: 0.41, ret.: 48.0, ret. prom.: 60.5
# ep.: 881, eps: 0.41, ret.: 82.0, ret. prom.: 61.0
# ep.: 882, eps: 0.41, ret.: 172.0, ret. prom.: 62.2
# ep.: 883, eps: 0.41, ret.: 61.0, ret. prom.: 62.4
# ep.: 884, eps: 0.41, ret.: 38.0, ret. prom.: 62.6
# ep.: 885, eps: 0.41, ret.: 34.0, ret. prom.: 62.6
# ep.: 886, eps: 0.41, ret.: 135.0, ret. prom.: 63.3
# ep.: 887, eps: 0.41, ret.: 20.0, ret. prom.: 62.7
# ep.: 888, eps: 0.41, ret.: 21.0, ret. prom.: 62.7
# ep.: 889, eps: 0.41, ret.: 86.0, ret. prom.: 63.2
# ep.: 890, eps: 0.41, ret.: 46.0, ret. prom.: 63.3
# ep.: 891, eps: 0.41, ret.: 118.0, ret. prom.: 64.0
# ep.: 892, eps: 0.41, ret.: 36.0, ret. prom.: 64.0
# ep.: 893, eps: 0.41, ret.: 35.0, ret. prom.: 63.1
# ep.: 894, eps: 0.41, ret.: 59.0, ret. prom.: 63.1
# ep.: 895, eps: 0.41, ret.: 37.0, ret. prom.: 63.3
# ep.: 896, eps: 0.41, ret.: 58.0, ret. prom.: 63.7
# ep.: 897, eps: 0.41, ret.: 35.0, ret. prom.: 63.5
# ep.: 898, eps: 0.41, ret.: 39.0, ret. prom.: 63.6
# ep.: 899, eps: 0.41, ret.: 37.0, ret. prom.: 63.4
# ep.: 900, eps: 0.41, ret.: 102.0, ret. prom.: 63.9
# ep.: 901, eps: 0.41, ret.: 35.0, ret. prom.: 63.4
# ep.: 902, eps: 0.41, ret.: 29.0, ret. prom.: 61.5
# ep.: 903, eps: 0.41, ret.: 33.0, ret. prom.: 61.6
# ep.: 904, eps: 0.40, ret.: 17.0, ret. prom.: 60.9
# ep.: 905, eps: 0.40, ret.: 115.0, ret. prom.: 61.8
# ep.: 906, eps: 0.40, ret.: 54.0, ret. prom.: 62.2
# ep.: 907, eps: 0.40, ret.: 66.0, ret. prom.: 62.5
# ep.: 908, eps: 0.40, ret.: 41.0, ret. prom.: 62.5
# ep.: 909, eps: 0.40, ret.: 39.0, ret. prom.: 61.9
# ep.: 910, eps: 0.40, ret.: 33.0, ret. prom.: 61.9
# ep.: 911, eps: 0.40, ret.: 37.0, ret. prom.: 61.5
# ep.: 912, eps: 0.40, ret.: 23.0, ret. prom.: 60.9
# ep.: 913, eps: 0.40, ret.: 65.0, ret. prom.: 60.3
# ep.: 914, eps: 0.40, ret.: 65.0, ret. prom.: 60.4
# ep.: 915, eps: 0.40, ret.: 22.0, ret. prom.: 59.7
# ep.: 916, eps: 0.40, ret.: 46.0, ret. prom.: 59.8
# ep.: 917, eps: 0.40, ret.: 66.0, ret. prom.: 59.9
# ep.: 918, eps: 0.40, ret.: 90.0, ret. prom.: 60.4
# ep.: 919, eps: 0.40, ret.: 47.0, ret. prom.: 60.0
# ep.: 920, eps: 0.40, ret.: 139.0, ret. prom.: 60.9
# ep.: 921, eps: 0.40, ret.: 98.0, ret. prom.: 61.5
# ep.: 922, eps: 0.40, ret.: 96.0, ret. prom.: 61.9
# ep.: 923, eps: 0.40, ret.: 60.0, ret. prom.: 61.4
# ep.: 924, eps: 0.40, ret.: 85.0, ret. prom.: 60.9
# ep.: 925, eps: 0.40, ret.: 30.0, ret. prom.: 60.0
# ep.: 926, eps: 0.40, ret.: 65.0, ret. prom.: 59.9
# ep.: 927, eps: 0.40, ret.: 97.0, ret. prom.: 60.0
# ep.: 928, eps: 0.40, ret.: 63.0, ret. prom.: 59.9
# ep.: 929, eps: 0.39, ret.: 17.0, ret. prom.: 59.9
# ep.: 930, eps: 0.39, ret.: 28.0, ret. prom.: 59.5
# ep.: 931, eps: 0.39, ret.: 85.0, ret. prom.: 60.0
# ep.: 932, eps: 0.39, ret.: 77.0, ret. prom.: 60.1
# ep.: 933, eps: 0.39, ret.: 26.0, ret. prom.: 59.2
# ep.: 934, eps: 0.39, ret.: 69.0, ret. prom.: 59.1
# ep.: 935, eps: 0.39, ret.: 67.0, ret. prom.: 59.2
# ep.: 936, eps: 0.39, ret.: 89.0, ret. prom.: 59.8
# ep.: 937, eps: 0.39, ret.: 150.0, ret. prom.: 60.9
# ep.: 938, eps: 0.39, ret.: 59.0, ret. prom.: 61.4
# ep.: 939, eps: 0.39, ret.: 18.0, ret. prom.: 60.5
# ep.: 940, eps: 0.39, ret.: 112.0, ret. prom.: 61.4
# ep.: 941, eps: 0.39, ret.: 94.0, ret. prom.: 62.0
# ep.: 942, eps: 0.39, ret.: 73.0, ret. prom.: 61.9
# ep.: 943, eps: 0.39, ret.: 188.0, ret. prom.: 62.7
# ep.: 944, eps: 0.39, ret.: 87.0, ret. prom.: 63.0
# ep.: 945, eps: 0.39, ret.: 23.0, ret. prom.: 63.0
# ep.: 946, eps: 0.39, ret.: 66.0, ret. prom.: 63.1
# ep.: 947, eps: 0.39, ret.: 137.0, ret. prom.: 64.2
# ep.: 948, eps: 0.39, ret.: 57.0, ret. prom.: 63.9
# ep.: 949, eps: 0.39, ret.: 22.0, ret. prom.: 63.4
# ep.: 950, eps: 0.39, ret.: 122.0, ret. prom.: 64.5
# ep.: 951, eps: 0.39, ret.: 103.0, ret. prom.: 64.4
# ep.: 952, eps: 0.39, ret.: 24.0, ret. prom.: 64.3
# ep.: 953, eps: 0.39, ret.: 98.0, ret. prom.: 64.5
# ep.: 954, eps: 0.39, ret.: 60.0, ret. prom.: 64.6
# ep.: 955, eps: 0.38, ret.: 126.0, ret. prom.: 64.3
# ep.: 956, eps: 0.38, ret.: 27.0, ret. prom.: 63.9
# ep.: 957, eps: 0.38, ret.: 102.0, ret. prom.: 63.8
# ep.: 958, eps: 0.38, ret.: 68.0, ret. prom.: 64.2
# ep.: 959, eps: 0.38, ret.: 72.0, ret. prom.: 64.7
# ep.: 960, eps: 0.38, ret.: 38.0, ret. prom.: 64.1
# ...
# ep.: 1203, eps: 0.30, ret.: 72.0, ret. prom.: 78.3
# ep.: 1204, eps: 0.30, ret.: 45.0, ret. prom.: 77.6
# ep.: 1205, eps: 0.30, ret.: 86.0, ret. prom.: 77.7
# ep.: 1206, eps: 0.30, ret.: 82.0, ret. prom.: 77.7
# ep.: 1207, eps: 0.30, ret.: 36.0, ret. prom.: 77.4
# ep.: 1208, eps: 0.30, ret.: 80.0, ret. prom.: 77.8
# ep.: 1209, eps: 0.30, ret.: 74.0, ret. prom.: 77.3
# ep.: 1210, eps: 0.30, ret.: 70.0, ret. prom.: 77.5
# ep.: 1211, eps: 0.30, ret.: 250.0, ret. prom.: 79.3
# ep.: 1212, eps: 0.30, ret.: 105.0, ret. prom.: 79.7
# ep.: 1213, eps: 0.30, ret.: 111.0, ret. prom.: 79.8
# ep.: 1214, eps: 0.30, ret.: 57.0, ret. prom.: 79.6
# ep.: 1215, eps: 0.30, ret.: 94.0, ret. prom.: 79.6
# ep.: 1216, eps: 0.30, ret.: 80.0, ret. prom.: 80.0
# ep.: 1217, eps: 0.30, ret.: 82.0, ret. prom.: 79.4
# ep.: 1218, eps: 0.30, ret.: 35.0, ret. prom.: 79.1
# ep.: 1219, eps: 0.30, ret.: 26.0, ret. prom.: 78.8
# ep.: 1220, eps: 0.30, ret.: 89.0, ret. prom.: 79.3
# ep.: 1221, eps: 0.29, ret.: 89.0, ret. prom.: 79.5
# ep.: 1222, eps: 0.29, ret.: 79.0, ret. prom.: 79.1
# ep.: 1223, eps: 0.29, ret.: 87.0, ret. prom.: 79.3
# ep.: 1224, eps: 0.29, ret.: 64.0, ret. prom.: 79.4
# ep.: 1225, eps: 0.29, ret.: 128.0, ret. prom.: 80.1
# ep.: 1226, eps: 0.29, ret.: 59.0, ret. prom.: 80.2
# ep.: 1227, eps: 0.29, ret.: 71.0, ret. prom.: 80.0
# ep.: 1228, eps: 0.29, ret.: 95.0, ret. prom.: 80.3
# ep.: 1229, eps: 0.29, ret.: 45.0, ret. prom.: 80.0
# ep.: 1230, eps: 0.29, ret.: 71.0, ret. prom.: 79.7
# ep.: 1231, eps: 0.29, ret.: 57.0, ret. prom.: 79.3
# ep.: 1232, eps: 0.29, ret.: 61.0, ret. prom.: 79.5
# ep.: 1233, eps: 0.29, ret.: 63.0, ret. prom.: 79.6
# ep.: 1234, eps: 0.29, ret.: 84.0, ret. prom.: 79.1
# ep.: 1235, eps: 0.29, ret.: 14.0, ret. prom.: 78.8
# ep.: 1236, eps: 0.29, ret.: 109.0, ret. prom.: 78.8
# ep.: 1237, eps: 0.29, ret.: 97.0, ret. prom.: 79.2
# ep.: 1238, eps: 0.29, ret.: 53.0, ret. prom.: 79.0
# ep.: 1239, eps: 0.29, ret.: 89.0, ret. prom.: 79.5
# ep.: 1240, eps: 0.29, ret.: 102.0, ret. prom.: 80.3
# ep.: 1241, eps: 0.29, ret.: 50.0, ret. prom.: 80.1
# ep.: 1242, eps: 0.29, ret.: 75.0, ret. prom.: 79.8
# ep.: 1243, eps: 0.29, ret.: 80.0, ret. prom.: 79.7
# ep.: 1244, eps: 0.29, ret.: 50.0, ret. prom.: 79.4
# ep.: 1245, eps: 0.29, ret.: 65.0, ret. prom.: 79.0
# ep.: 1246, eps: 0.29, ret.: 80.0, ret. prom.: 78.9
# ep.: 1247, eps: 0.29, ret.: 95.0, ret. prom.: 78.4
# ep.: 1248, eps: 0.29, ret.: 38.0, ret. prom.: 77.9
# ep.: 1249, eps: 0.29, ret.: 65.0, ret. prom.: 78.2
# ep.: 1250, eps: 0.29, ret.: 36.0, ret. prom.: 78.0
# ep.: 1251, eps: 0.29, ret.: 51.0, ret. prom.: 77.4
# ep.: 1252, eps: 0.29, ret.: 28.0, ret. prom.: 76.6
# ep.: 1253, eps: 0.29, ret.: 68.0, ret. prom.: 76.2
# ep.: 1254, eps: 0.29, ret.: 59.0, ret. prom.: 75.9
# ep.: 1255, eps: 0.28, ret.: 167.0, ret. prom.: 76.4
# ep.: 1256, eps: 0.28, ret.: 49.0, ret. prom.: 76.3
# ep.: 1257, eps: 0.28, ret.: 78.0, ret. prom.: 75.8
# ep.: 1258, eps: 0.28, ret.: 38.0, ret. prom.: 75.5
# ep.: 1259, eps: 0.28, ret.: 47.0, ret. prom.: 75.3
# ep.: 1260, eps: 0.28, ret.: 50.0, ret. prom.: 75.0
# ep.: 1261, eps: 0.28, ret.: 30.0, ret. prom.: 74.8
# ep.: 1262, eps: 0.28, ret.: 90.0, ret. prom.: 74.1
# ep.: 1263, eps: 0.28, ret.: 23.0, ret. prom.: 73.5
# ep.: 1264, eps: 0.28, ret.: 46.0, ret. prom.: 73.1
# ep.: 1265, eps: 0.28, ret.: 186.0, ret. prom.: 73.4
# ep.: 1266, eps: 0.28, ret.: 115.0, ret. prom.: 74.0
# ep.: 1267, eps: 0.28, ret.: 99.0, ret. prom.: 74.5
# ep.: 1268, eps: 0.28, ret.: 38.0, ret. prom.: 73.3
# ep.: 1269, eps: 0.28, ret.: 75.0, ret. prom.: 73.6
# ep.: 1270, eps: 0.28, ret.: 114.0, ret. prom.: 73.6
# ep.: 1271, eps: 0.28, ret.: 148.0, ret. prom.: 74.2
# ep.: 1272, eps: 0.28, ret.: 68.0, ret. prom.: 74.2
# ep.: 1273, eps: 0.28, ret.: 33.0, ret. prom.: 73.6
# ep.: 1274, eps: 0.28, ret.: 105.0, ret. prom.: 73.6
# ep.: 1275, eps: 0.28, ret.: 112.0, ret. prom.: 73.9
# ep.: 1276, eps: 0.28, ret.: 48.0, ret. prom.: 73.9
# ep.: 1277, eps: 0.28, ret.: 282.0, ret. prom.: 76.0
# ep.: 1278, eps: 0.28, ret.: 102.0, ret. prom.: 76.7
# ep.: 1279, eps: 0.28, ret.: 113.0, ret. prom.: 77.3
# ep.: 1280, eps: 0.28, ret.: 147.0, ret. prom.: 77.9
# ep.: 1281, eps: 0.28, ret.: 60.0, ret. prom.: 77.8
# ep.: 1282, eps: 0.28, ret.: 17.0, ret. prom.: 76.8
# ep.: 1283, eps: 0.28, ret.: 50.0, ret. prom.: 76.1
# ep.: 1284, eps: 0.28, ret.: 35.0, ret. prom.: 76.0
# ep.: 1285, eps: 0.28, ret.: 130.0, ret. prom.: 76.2
# ep.: 1286, eps: 0.28, ret.: 115.0, ret. prom.: 76.4
# ep.: 1287, eps: 0.28, ret.: 39.0, ret. prom.: 76.3
# ep.: 1288, eps: 0.28, ret.: 88.0, ret. prom.: 76.7
# ep.: 1289, eps: 0.28, ret.: 59.0, ret. prom.: 76.5
# ep.: 1290, eps: 0.28, ret.: 79.0, ret. prom.: 76.1
# ep.: 1291, eps: 0.27, ret.: 53.0, ret. prom.: 76.0
# ep.: 1292, eps: 0.27, ret.: 65.0, ret. prom.: 75.8
# ep.: 1293, eps: 0.27, ret.: 77.0, ret. prom.: 76.2
# ep.: 1294, eps: 0.27, ret.: 107.0, ret. prom.: 77.0
# ep.: 1295, eps: 0.27, ret.: 109.0, ret. prom.: 77.4
# ep.: 1296, eps: 0.27, ret.: 70.0, ret. prom.: 77.2
# ep.: 1297, eps: 0.27, ret.: 86.0, ret. prom.: 77.6
# ep.: 1298, eps: 0.27, ret.: 38.0, ret. prom.: 77.4
# ep.: 1299, eps: 0.27, ret.: 80.0, ret. prom.: 77.5
# ep.: 1300, eps: 0.27, ret.: 105.0, ret. prom.: 77.5
# ep.: 1301, eps: 0.27, ret.: 79.0, ret. prom.: 78.2
# ep.: 1302, eps: 0.27, ret.: 161.0, ret. prom.: 79.4
# ep.: 1303, eps: 0.27, ret.: 84.0, ret. prom.: 79.5
# ep.: 1304, eps: 0.27, ret.: 66.0, ret. prom.: 79.7
# ep.: 1305, eps: 0.27, ret.: 103.0, ret. prom.: 79.9
# ep.: 1306, eps: 0.27, ret.: 99.0, ret. prom.: 80.0
# ep.: 1307, eps: 0.27, ret.: 32.0, ret. prom.: 80.0
# ep.: 1308, eps: 0.27, ret.: 134.0, ret. prom.: 80.5
# ep.: 1309, eps: 0.27, ret.: 90.0, ret. prom.: 80.7
# ep.: 1310, eps: 0.27, ret.: 49.0, ret. prom.: 80.5
# ep.: 1311, eps: 0.27, ret.: 71.0, ret. prom.: 78.7
# ep.: 1312, eps: 0.27, ret.: 52.0, ret. prom.: 78.2
# ep.: 1313, eps: 0.27, ret.: 52.0, ret. prom.: 77.6
# ep.: 1314, eps: 0.27, ret.: 47.0, ret. prom.: 77.5
# ep.: 1315, eps: 0.27, ret.: 95.0, ret. prom.: 77.5
# ep.: 1316, eps: 0.27, ret.: 95.0, ret. prom.: 77.6
# ep.: 1317, eps: 0.27, ret.: 80.0, ret. prom.: 77.6
# ep.: 1318, eps: 0.27, ret.: 60.0, ret. prom.: 77.9
# ep.: 1319, eps: 0.27, ret.: 18.0, ret. prom.: 77.8
# ep.: 1320, eps: 0.27, ret.: 80.0, ret. prom.: 77.7
# ep.: 1321, eps: 0.27, ret.: 25.0, ret. prom.: 77.0
# ep.: 1322, eps: 0.27, ret.: 110.0, ret. prom.: 77.4
# ep.: 1323, eps: 0.27, ret.: 96.0, ret. prom.: 77.5
# ep.: 1324, eps: 0.27, ret.: 102.0, ret. prom.: 77.8
# ep.: 1325, eps: 0.27, ret.: 98.0, ret. prom.: 77.5
# ep.: 1326, eps: 0.27, ret.: 101.0, ret. prom.: 78.0
# ep.: 1327, eps: 0.27, ret.: 89.0, ret. prom.: 78.1
# ep.: 1328, eps: 0.26, ret.: 55.0, ret. prom.: 77.7
# ep.: 1329, eps: 0.26, ret.: 109.0, ret. prom.: 78.4
# ep.: 1330, eps: 0.26, ret.: 81.0, ret. prom.: 78.5
# ep.: 1331, eps: 0.26, ret.: 75.0, ret. prom.: 78.7
# ep.: 1332, eps: 0.26, ret.: 98.0, ret. prom.: 79.0
# ep.: 1333, eps: 0.26, ret.: 97.0, ret. prom.: 79.4
# ep.: 1334, eps: 0.26, ret.: 68.0, ret. prom.: 79.2
# ep.: 1335, eps: 0.26, ret.: 102.0, ret. prom.: 80.1
# ep.: 1336, eps: 0.26, ret.: 149.0, ret. prom.: 80.5
# ep.: 1337, eps: 0.26, ret.: 145.0, ret. prom.: 81.0
# ep.: 1338, eps: 0.26, ret.: 34.0, ret. prom.: 80.8
# ep.: 1339, eps: 0.26, ret.: 128.0, ret. prom.: 81.2
# ep.: 1340, eps: 0.26, ret.: 95.0, ret. prom.: 81.1
# ep.: 1341, eps: 0.26, ret.: 109.0, ret. prom.: 81.7
# ep.: 1342, eps: 0.26, ret.: 71.0, ret. prom.: 81.6
# ep.: 1343, eps: 0.26, ret.: 83.0, ret. prom.: 81.7
# ep.: 1344, eps: 0.26, ret.: 71.0, ret. prom.: 81.9
# ep.: 1345, eps: 0.26, ret.: 72.0, ret. prom.: 82.0
# ep.: 1346, eps: 0.26, ret.: 88.0, ret. prom.: 82.0
# ep.: 1347, eps: 0.26, ret.: 135.0, ret. prom.: 82.4
# ep.: 1348, eps: 0.26, ret.: 115.0, ret. prom.: 83.2
# ep.: 1349, eps: 0.26, ret.: 62.0, ret. prom.: 83.2
# ep.: 1350, eps: 0.26, ret.: 80.0, ret. prom.: 83.6
# ep.: 1351, eps: 0.26, ret.: 81.0, ret. prom.: 83.9
# ep.: 1352, eps: 0.26, ret.: 79.0, ret. prom.: 84.4
# ep.: 1353, eps: 0.26, ret.: 21.0, ret. prom.: 84.0
# ep.: 1354, eps: 0.26, ret.: 86.0, ret. prom.: 84.2
# ep.: 1355, eps: 0.26, ret.: 59.0, ret. prom.: 83.1
# ep.: 1356, eps: 0.26, ret.: 73.0, ret. prom.: 83.4
# ep.: 1357, eps: 0.26, ret.: 41.0, ret. prom.: 83.0
# ep.: 1358, eps: 0.26, ret.: 101.0, ret. prom.: 83.6
# ep.: 1359, eps: 0.26, ret.: 100.0, ret. prom.: 84.2
# ep.: 1360, eps: 0.26, ret.: 48.0, ret. prom.: 84.2
# ep.: 1361, eps: 0.26, ret.: 80.0, ret. prom.: 84.7
# ep.: 1362, eps: 0.26, ret.: 64.0, ret. prom.: 84.4
# ep.: 1363, eps: 0.26, ret.: 69.0, ret. prom.: 84.8
# ep.: 1364, eps: 0.26, ret.: 67.0, ret. prom.: 85.1
# ep.: 1365, eps: 0.26, ret.: 142.0, ret. prom.: 84.6
# ep.: 1366, eps: 0.25, ret.: 30.0, ret. prom.: 83.8
# ep.: 1367, eps: 0.25, ret.: 140.0, ret. prom.: 84.2
# ep.: 1368, eps: 0.25, ret.: 110.0, ret. prom.: 84.9
# ep.: 1369, eps: 0.25, ret.: 70.0, ret. prom.: 84.8
# ep.: 1370, eps: 0.25, ret.: 140.0, ret. prom.: 85.1
# ep.: 1371, eps: 0.25, ret.: 144.0, ret. prom.: 85.1
# ep.: 1372, eps: 0.25, ret.: 71.0, ret. prom.: 85.1
# ep.: 1373, eps: 0.25, ret.: 119.0, ret. prom.: 86.0
# ep.: 1374, eps: 0.25, ret.: 120.0, ret. prom.: 86.1
# ep.: 1375, eps: 0.25, ret.: 53.0, ret. prom.: 85.5
# ep.: 1376, eps: 0.25, ret.: 71.0, ret. prom.: 85.8
# ep.: 1377, eps: 0.25, ret.: 87.0, ret. prom.: 83.8
# ep.: 1378, eps: 0.25, ret.: 100.0, ret. prom.: 83.8
# ep.: 1379, eps: 0.25, ret.: 81.0, ret. prom.: 83.5
# ep.: 1380, eps: 0.25, ret.: 102.0, ret. prom.: 83.0
# ep.: 1381, eps: 0.25, ret.: 71.0, ret. prom.: 83.1
# ep.: 1382, eps: 0.25, ret.: 57.0, ret. prom.: 83.5
# ep.: 1383, eps: 0.25, ret.: 114.0, ret. prom.: 84.2
# ep.: 1384, eps: 0.25, ret.: 92.0, ret. prom.: 84.7
# ep.: 1385, eps: 0.25, ret.: 135.0, ret. prom.: 84.8
# ep.: 1386, eps: 0.25, ret.: 58.0, ret. prom.: 84.2
# ep.: 1387, eps: 0.25, ret.: 74.0, ret. prom.: 84.6
# ep.: 1388, eps: 0.25, ret.: 80.0, ret. prom.: 84.5
# ep.: 1389, eps: 0.25, ret.: 80.0, ret. prom.: 84.7
# ep.: 1390, eps: 0.25, ret.: 67.0, ret. prom.: 84.6
# ep.: 1391, eps: 0.25, ret.: 128.0, ret. prom.: 85.3
# ep.: 1392, eps: 0.25, ret.: 170.0, ret. prom.: 86.4
# ep.: 1393, eps: 0.25, ret.: 92.0, ret. prom.: 86.5
# ep.: 1394, eps: 0.25, ret.: 108.0, ret. prom.: 86.5
# ep.: 1395, eps: 0.25, ret.: 128.0, ret. prom.: 86.7
# ep.: 1396, eps: 0.25, ret.: 106.0, ret. prom.: 87.1
# ep.: 1397, eps: 0.25, ret.: 86.0, ret. prom.: 87.1
# ep.: 1398, eps: 0.25, ret.: 50.0, ret. prom.: 87.2
# ep.: 1399, eps: 0.25, ret.: 36.0, ret. prom.: 86.8
# ep.: 1400, eps: 0.25, ret.: 62.0, ret. prom.: 86.3
# ep.: 1401, eps: 0.25, ret.: 138.0, ret. prom.: 86.9
# ep.: 1402, eps: 0.25, ret.: 61.0, ret. prom.: 85.9
# ep.: 1403, eps: 0.25, ret.: 92.0, ret. prom.: 86.0
# ep.: 1404, eps: 0.25, ret.: 118.0, ret. prom.: 86.5
# ep.: 1405, eps: 0.25, ret.: 70.0, ret. prom.: 86.2
# ep.: 1406, eps: 0.24, ret.: 92.0, ret. prom.: 86.1
# ep.: 1407, eps: 0.24, ret.: 51.0, ret. prom.: 86.3
# ep.: 1408, eps: 0.24, ret.: 108.0, ret. prom.: 86.0
# ep.: 1409, eps: 0.24, ret.: 173.0, ret. prom.: 86.9
# ep.: 1410, eps: 0.24, ret.: 49.0, ret. prom.: 86.9
# ep.: 1411, eps: 0.24, ret.: 65.0, ret. prom.: 86.8
# ep.: 1412, eps: 0.24, ret.: 117.0, ret. prom.: 87.5
# ep.: 1413, eps: 0.24, ret.: 78.0, ret. prom.: 87.7
# ep.: 1414, eps: 0.24, ret.: 67.0, ret. prom.: 87.9
# ep.: 1415, eps: 0.24, ret.: 226.0, ret. prom.: 89.2
# ep.: 1416, eps: 0.24, ret.: 71.0, ret. prom.: 89.0
# ep.: 1417, eps: 0.24, ret.: 95.0, ret. prom.: 89.2
# ep.: 1418, eps: 0.24, ret.: 49.0, ret. prom.: 89.0
# ep.: 1419, eps: 0.24, ret.: 81.0, ret. prom.: 89.7
# ep.: 1420, eps: 0.24, ret.: 64.0, ret. prom.: 89.5
# ep.: 1421, eps: 0.24, ret.: 52.0, ret. prom.: 89.8
# ep.: 1422, eps: 0.24, ret.: 113.0, ret. prom.: 89.8
# ep.: 1423, eps: 0.24, ret.: 84.0, ret. prom.: 89.7
# ep.: 1424, eps: 0.24, ret.: 95.0, ret. prom.: 89.6
# ep.: 1425, eps: 0.24, ret.: 99.0, ret. prom.: 89.6
# ep.: 1426, eps: 0.24, ret.: 104.0, ret. prom.: 89.7
# ep.: 1427, eps: 0.24, ret.: 76.0, ret. prom.: 89.5
# ep.: 1428, eps: 0.24, ret.: 100.0, ret. prom.: 90.0
# ep.: 1429, eps: 0.24, ret.: 76.0, ret. prom.: 89.7
# ep.: 1430, eps: 0.24, ret.: 73.0, ret. prom.: 89.6
# ep.: 1431, eps: 0.24, ret.: 108.0, ret. prom.: 89.9
# ep.: 1432, eps: 0.24, ret.: 86.0, ret. prom.: 89.8
# ep.: 1433, eps: 0.24, ret.: 116.0, ret. prom.: 90.0
# ep.: 1434, eps: 0.24, ret.: 81.0, ret. prom.: 90.1
# ep.: 1435, eps: 0.24, ret.: 60.0, ret. prom.: 89.7
# ep.: 1436, eps: 0.24, ret.: 63.0, ret. prom.: 88.8
# ep.: 1437, eps: 0.24, ret.: 116.0, ret. prom.: 88.5
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-cacb8ae21515> in <cell line: 36>()
#      51
#      52         # Ejecutamos accion
# ---> 53         next_state, reward, done, _ = env.step(action)
#      54         next_state = discretize(next_state)
#      55
#
# /usr/local/lib/python3.10/dist-packages/gym/wrappers/record_video.py in step(self, action)
#     161             if self.recording:
#     162                 assert self.video_recorder is not None
# --> 163                 self.video_recorder.capture_frame()
#     164                 self.recorded_frames += 1
#     165                 if self.video_length > 0:
#
# /usr/local/lib/python3.10/dist-packages/gym/wrappers/monitoring/video_recorder.py in capture_frame(self)
#     183         """Render the given `env` and add the resulting frame to the video."""
#     184         if self.render_mode is None:
# --> 185             frame = self.env.render(mode="rgb_array")
#     186         else:
#     187             frame = self.env.render()
#
# /usr/local/lib/python3.10/dist-packages/gym/core.py in render(self, *args, **kwargs)
#      56             )
#      57
# ---> 58         return render_func(self, *args, **kwargs)
#      59
#      60     return render
#
# /usr/local/lib/python3.10/dist-packages/gym/core.py in render(self, *args, **kwargs)
#     419     ) -> Optional[Union[RenderFrame, List[RenderFrame]]]:
#     420         """Renders the environment."""
# --> 421         return self.env.render(*args, **kwargs)
#     422
#     423     def close(self):
#
# /usr/local/lib/python3.10/dist-packages/gym/core.py in render(self, *args, **kwargs)
#      56             )
#      57
# ---> 58         return render_func(self, *args, **kwargs)
#      59
#      60     return render
#
# /usr/local/lib/python3.10/dist-packages/gym/wrappers/order_enforcing.py in render(self, *args, **kwargs)
#      49                 "set `disable_render_order_enforcing=True` on the OrderEnforcer wrapper."
#      50             )
# ---> 51         return self.env.render(*args, **kwargs)
#      52
#      53     @property
#
# /usr/local/lib/python3.10/dist-packages/gym/core.py in render(self, *args, **kwargs)
#      56             )
#      57
# ---> 58         return render_func(self, *args, **kwargs)
#      59
#      60     return render
#
# /usr/local/lib/python3.10/dist-packages/gym/core.py in render(self, *args, **kwargs)
#     419     ) -> Optional[Union[RenderFrame, List[RenderFrame]]]:
#     420         """Renders the environment."""
# --> 421         return self.env.render(*args, **kwargs)
#     422
#     423     def close(self):
#
# /usr/local/lib/python3.10/dist-packages/gym/core.py in render(self, *args, **kwargs)
#      56             )
#      57
# ---> 58         return render_func(self, *args, **kwargs)
#      59
#      60     return render
#
# /usr/local/lib/python3.10/dist-packages/gym/wrappers/env_checker.py in render(self, *args, **kwargs)
#      53             return env_render_passive_checker(self.env, *args, **kwargs)
#      54         else:
# ---> 55             return self.env.render(*args, **kwargs)
#
# /usr/local/lib/python3.10/dist-packages/gym/core.py in render(self, *args, **kwargs)
#      56             )
#      57
# ---> 58         return render_func(self, *args, **kwargs)
#      59
#      60     return render
#
# /usr/local/lib/python3.10/dist-packages/gym/envs/classic_control/cartpole.py in render(self, mode)
#     215             return self.renderer.get_renders()
#     216         else:
# --> 217             return self._render(mode)
#     218
#     219     def _render(self, mode="human"):
#
# /usr/local/lib/python3.10/dist-packages/gym/envs/classic_control/cartpole.py in _render(self, mode)
#     304         elif mode in {"rgb_array", "single_rgb_array"}:
#     305             return np.transpose(
# --> 306                 np.array(pygame.surfarray.pixels3d(self.screen)), axes=(1, 0, 2)
#     307             )
#     308
#
# KeyboardInterrupt:

# %%
# Visualiza el último episodio (desde el env.reset() hasta el env.close())
env.close()
show_video()

print("Recompensa {}".format(episode_reward))
# Out:
# <video alt="test" autoplay
#                 loop controls style="height: 400px;">
#                 <source src="data:video/mp4;base64,..." type="video/mp4" />
#              </video>
# Recompensa 64.0
